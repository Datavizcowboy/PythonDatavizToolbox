# %% [markdown]
# # Scatter Plot

# %% [markdown]
# In this notebook the basics of reading a CSV file, assigning the values to a couple of arrays and plotting these arrays in cartesian axis is explained.

# %% [markdown]
# Matplotlib library allows us to create simple yet useful plots in Python

# %%
import matplotlib.pyplot as pl
pl.rcParams['figure.figsize'] = [12, 8]

# %% [markdown]
# We use a random distribution of dots in the cartesian space stored in the DATA folder

# %%
data_path = '../../DATA/UnequalVar.csv'

# %% [markdown]
# Two empty arrays will store the x and y data contained in the input file

# %%
x=[]
y=[]

# %% [markdown]
# The input file is read line by line, being the numbers split by tabulation and associated with each array. In this step we also convert the string data format of the first and second column into float type numbers with the built-in float( ) function.

# %%
fp = open(data_path, 'r')  

for g in fp.readlines():
    line=g.strip()
    data=line.split('\t')
    x.append(float(data[0]))
    y.append(float(data[1]))

fp.close()

# %% [markdown]
# The function scatter creates the plot. Parameters s and color refer to the radius of the dots and color code we apply. Gridlines are also added as well as title and axis labels

# %%
fig, ax = pl.subplots(1,1)
ax.scatter(x,y, s=1, color='k')
ax.grid(linestyle='dotted',linewidth=.2, alpha=0.8)    
ax.set_xlabel('X values', fontsize=12,linespacing=4.2)
ax.set_ylabel('Y values', fontsize=12)
pl.title('Scatter Plot')
pl.show()
