# %% [markdown]
# # E-Commerce Dataset

# %% [markdown]
# Analytics on E-commerce

# %% [markdown]
# Libraries we need are imported first

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Data used in this exercise is stored in the DATA folder

# %%
data_path = '../../../DATA/ecommerce_orig.txt'

# %% [markdown]
# The dataframe is created using the .read_csv function of Pandas

# %%
data = pd.read_csv(data_path, delimiter = "\t")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155988 entries, 0 to 155987
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   weeknumberbyyear            155988 non-null  object
#  1   TrafficSourceType           155988 non-null  object
#  2   Device                      155988 non-null  object
#  3   VisitorType                 155988 non-null  object
#  4   NonBounceVisit              155988 non-null  object
#  5   HomePageWasVisited          155988 non-null  object
#  6   ProductPageWasVisited       155988 non-null  object
#  7   VisitToProductAfterListing  155988 non-null  object
#  8   SiteSearchWasUsed           155988 non-null  object
#  9   VisitWithAddtoBag           155988 non-null  object
#  10  VisitWithAddtoWishlist      155988 non-null  object
#  11  ShippingAddressWasVisited   155988 non-null  object
#  12  PaymentPageWasVisited       155988 non-null  object
#  13  ReviewOrderPageWasVisited   155988 non-null  object
#  14  ConfirmationPageWasVisited  155988 non-null  object
#  15  Visits                      155988 non-null  int64
#  16  Revenue                     155988 non-null  float64
#  17  Orders                      155988 non-null  int64
# dtypes: float64(1), int64(2), object(15)
# memory usage: 21.4+ MB

# %% [markdown]
# The original CSV file is structured as a dataframe with the corresponding categories

# %% [markdown]
# After renaming the variable of the dataframe, we use .describe() to see essential statistics for each variable

# %%
data.describe()
# Out:
#               Visits       Revenue         Orders
# count  155988.000000  1.559880e+05  155988.000000
# mean      227.485441  1.595634e+03       2.098226
# std      1556.122164  1.215119e+04      14.548048
# min         1.000000  0.000000e+00       0.000000
# 25%         1.000000  0.000000e+00       0.000000
# 50%         2.000000  0.000000e+00       0.000000
# 75%        10.000000  2.615880e+02       1.000000
# max     58182.000000  1.348615e+06    1605.000000

# %% [markdown]
# We remove the rows where revenue is zero.

# %%
data = data[data['Revenue'] > 0] 
data
# Out:
#        weeknumberbyyear TrafficSourceType   Device VisitorType NonBounceVisit  \
# 4               2016-01        Affiliates  Desktop         New            Yes
# 7               2016-01        Affiliates  Desktop         New            Yes
# 12              2016-01        Affiliates  Desktop         New            Yes
# 27              2016-01        Affiliates  Desktop         New            Yes
# 32              2016-01        Affiliates  Desktop   Returning            Yes
# ...                 ...               ...      ...         ...            ...
# 155946          2017-01         Referrals   Mobile   Returning            Yes
# 155952          2017-01         Referrals   Mobile   Returning            Yes
# 155959          2017-01         Referrals   Tablet         New            Yes
# 155976          2017-01         Referrals   Tablet   Returning            Yes
# 155986          2017-01         Referrals   Tablet   Returning            Yes
#
#        HomePageWasVisited ProductPageWasVisited VisitToProductAfterListing  \
# 4                      No                   Yes                         No
# 7                      No                   Yes                         No
# 12                     No                   Yes                        Yes
# 27                    Yes                   Yes                        Yes
# 32                     No                   Yes                         No
# ...                   ...                   ...                        ...
# 155946                Yes                   Yes                         No
# 155952                Yes                   Yes                        Yes
# 155959                 No                   Yes                         No
# 155976                 No                   Yes                         No
# 155986                Yes                   Yes                        Yes
#
#        SiteSearchWasUsed VisitWithAddtoBag VisitWithAddtoWishlist  \
# 4                     No                No                     No
# 7                     No               Yes                     No
# 12                    No               Yes                     No
# 27                   Yes               Yes                    Yes
# 32                    No                No                     No
# ...                  ...               ...                    ...
# 155946                No               Yes                     No
# 155952               Yes               Yes                     No
# 155959               Yes               Yes                     No
# 155976                No               Yes                     No
# 155986                No               Yes                     No
#
#        ShippingAddressWasVisited PaymentPageWasVisited  \
# 4                            Yes                   Yes
# 7                             No                   Yes
# 12                            No                   Yes
# 27                           Yes                   Yes
# 32                            No                    No
# ...                          ...                   ...
# 155946                        No                    No
# 155952                        No                   Yes
# 155959                        No                   Yes
# 155976                        No                   Yes
# 155986                        No                    No
#
#        ReviewOrderPageWasVisited ConfirmationPageWasVisited  Visits   Revenue  \
# 4                            Yes                        Yes       4   354.150
# 7                            Yes                        Yes       3  3097.844
# 12                           Yes                        Yes       1  1459.481
# 27                           Yes                        Yes       3   632.951
# 32                           Yes                        Yes       5    89.875
# ...                          ...                        ...     ...       ...
# 155946                       Yes                        Yes       3   186.135
# 155952                       Yes                        Yes       5   195.000
# 155959                       Yes                        Yes       1   421.405
# 155976                       Yes                        Yes       4   308.066
# 155986                       Yes                        Yes       6   155.718
#
#         Orders
# 4            1
# 7            3
# 12           1
# 27           2
# 32           1
# ...        ...
# 155946       1
# 155952       1
# 155959       2
# 155976       1
# 155986       1
#
# [48784 rows x 18 columns]

# %% [markdown]
# We now make scatterplots for a number of variables

# %%
pd.plotting.scatter_matrix(data[['VisitorType', 'Revenue', 'Orders']],s=4,c='k',hist_kwds={'color':['black']});

# %%
pl.rcParams['font.family'] = "Arial"
pl.rcParams['font.size'] = "6"
fig, ax = pl.subplots(4,3,figsize=(10, 15)) 
fig.tight_layout()
fig.subplots_adjust(hspace=0.2)
data.boxplot('Visits', by='TrafficSourceType', ax=ax[0,0], showfliers=False);
data.boxplot('Visits', by='VisitorType', ax=ax[0,1], showfliers=False);
data.boxplot('Visits', by='Device', ax=ax[0,2], showfliers=False);
data.boxplot('Revenue', by='TrafficSourceType', ax=ax[1,0], showfliers=False);
data.boxplot('Revenue', by='VisitorType', ax=ax[1,1], showfliers=False);
data.boxplot('Revenue', by='Device', ax=ax[1,2], showfliers=False);
data.boxplot('Orders', by='TrafficSourceType', ax=ax[2,0], showfliers=False);
data.boxplot('Orders', by='VisitorType', ax=ax[2,1], showfliers=False);
data.boxplot('Orders', by='Device', ax=ax[2,2], showfliers=False);
data.boxplot('Orders', by='TrafficSourceType', ax=ax[3,0], showfliers=False);
data.boxplot('Orders', by='VisitorType', ax=ax[3,1], showfliers=False);
data.boxplot('Orders', by='Device', ax=ax[3,2], showfliers=False);
