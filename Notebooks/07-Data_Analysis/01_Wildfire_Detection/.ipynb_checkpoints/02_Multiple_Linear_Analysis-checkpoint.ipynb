# %% [markdown]
# # Chile Wildfire Hotspots Dataset

# %% [markdown]
# Chile Hotspots

# %% [markdown]
# Libraries we need are imported first

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
import statsmodels.api as sm
import statsmodels.formula.api as smf 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Data used in this exercise is stored in the DATA folder

# %%
data = '../../../DATA/chile_fire_cluster_sequence_v2.json'

# %% [markdown]
# The dataframe is created using the .read_csv function of Pandas

# %%
hotspot = pd.read_json(data)
# hotspot.info()

# %% [markdown]
# The original CSV file is structured as a dataframe with the corresponding categories

# %%
hotspot = hotspot[hotspot['mir_bt'].notna()]
hotspot = hotspot[hotspot['frp'].notna()]

# %% [markdown]
# After renaming the variable of the dataframe, we use .describe() to see essential statistics for each variable

# %% [markdown]
# ## Scatter Plots

# %%
sats = hotspot['satellite'].unique().tolist()

# %%
sat_stat = hotspot['satellite'].value_counts()
sat_stat
# Out:
# satellite
# SUOMI-NPP      10695
# NOAA-20        10155
# MetOp-B         1438
# MetOp-C         1435
# SENTINEL-3B     1371
# TERRA           1173
# AQUA            1024
# SENTINEL-3A      827
# Name: count, dtype: int64

# %%
colors_sat = ['red','blue','cyan','yellow','black','green','magenta','grey']
mapped = dict(zip(sats,colors_sat))
# colors = {'D':'tab:blue', 'E':'tab:orange', 'F':'tab:green', 'G':'tab:red', 'H':'tab:purple', 'I':'tab:brown', 'J':'tab:pink'}

# %%
X = hotspot[['mir_bt']]-hotspot[['tir_bt']]
Y = hotspot[['frp']]

# %%
fig, ax = pl.subplots(figsize=(8, 4)) 
gsd = pl.scatter(X, Y, c =hotspot['satellite'].map(mapped), s=4)
handlelist = [pl.plot([], marker="o", ls="", color=color)[0] for color in colors_sat]
pl.legend(handlelist,sats,loc='upper left')

# %% [markdown]
# ## Polynomial Regression

# %%
hotspot = hotspot[hotspot['satellite'].str.contains('AQUA')==True]
hotspot = hotspot[hotspot['confidence'] > 0.9]

# %%
poly = smf.ols(formula='frp ~ 0 + I(mir_bt ** 4)', data=hotspot).fit()
poly.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    frp   R-squared (uncentered):                   0.604
# Model:                            OLS   Adj. R-squared (uncentered):              0.603
# Method:                 Least Squares   F-statistic:                              853.7
# Date:                Wed, 06 Aug 2025   Prob (F-statistic):                   1.08e-114
# Time:                        14:25:20   Log-Likelihood:                         -4165.6
# No. Observations:                 561   AIC:                                      8333.
# Df Residuals:                     560   BIC:                                      8338.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# I(mir_bt ** 4)  2.502e-08   8.56e-10     29.218      0.000    2.33e-08    2.67e-08
# ==============================================================================
# Omnibus:                      566.549   Durbin-Watson:                   0.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20608.675
# Skew:                           4.658   Prob(JB):                         0.00
# Kurtosis:                      31.194   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = pd.DataFrame({'mir_bt': np.linspace(hotspot.mir_bt.min(), hotspot.mir_bt.max(), 100)})
ax = hotspot.plot.scatter('mir_bt','frp',s=.5,color='k',alpha=0.2)
ax.plot(x.mir_bt, poly.predict(x), 'g-', label='Poly n=2 $R^2$=%.2f' % poly.rsquared,alpha=0.9)
# ax.set_ylim(0.1,1.1)
