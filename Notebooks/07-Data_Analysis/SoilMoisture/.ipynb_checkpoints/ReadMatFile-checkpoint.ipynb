# %% [markdown]
# # Chile Wildfire Hotspots Dataset

# %% [markdown]
# Chile Hotspots

# %% [markdown]
# Libraries we need are imported first

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Data used in this exercise is stored in the DATA folder

# %%
data = '../../../DATA/chile_fire_cluster_sequence_v2.json'

# %% [markdown]
# The dataframe is created using the .read_csv function of Pandas

# %%
hotspot = pd.read_json(data)

# %% [markdown]
# The original CSV file is structured as a dataframe with the corresponding categories

# %%
hotspot
# Out:
#               id        lat        lon     gsd          acquisition_time  \
# 0      340503774 -37.573338 -72.809982   375.0 2023-02-20 06:24:06+00:00
# 1      340482670 -37.574661 -72.804817   750.0 2023-02-20 05:32:20+00:00
# 2      340482669 -37.572521 -72.815674   750.0 2023-02-20 05:32:20+00:00
# 3      340482981 -37.574902 -72.813324   375.0 2023-02-20 05:32:09+00:00
# 4      340482980 -37.575958 -72.807961   375.0 2023-02-20 05:32:09+00:00
# ...          ...        ...        ...     ...                       ...
# 60841  335107255 -37.501709 -72.593956   375.0 2023-02-02 18:30:02+00:00
# 60842  335107257 -37.498184 -72.594635   375.0 2023-02-02 18:30:02+00:00
# 60843  335107254 -37.501087 -72.589027   375.0 2023-02-02 18:30:02+00:00
# 60844  335107256 -37.497562 -72.589722   375.0 2023-02-02 18:30:02+00:00
# 60845  335014392 -37.173077 -72.943893  1000.0 2023-02-02 14:43:13+00:00
#
#                  detection_time      mir_bt      tir_bt  confidence  \
# 0     2023-02-20 11:14:14+00:00  300.264648  286.906799    0.500000
# 1     2023-02-20 07:15:37+00:00  295.815796  287.405548    0.650321
# 2     2023-02-20 07:15:37+00:00  291.642822  287.766937    0.505038
# 3     2023-02-20 07:16:58+00:00  304.782867  287.029938    0.500000
# 4     2023-02-20 07:16:58+00:00  327.564240  288.805969    0.500000
# ...                         ...         ...         ...         ...
# 60841 2023-02-02 20:23:03+00:00  333.399139  308.330200    0.500000
# 60842 2023-02-02 20:23:03+00:00  301.725189  311.209747    0.250000
# 60843 2023-02-02 20:23:03+00:00  336.259949  311.073761    0.500000
# 60844 2023-02-02 20:23:03+00:00  336.952362  310.423584    0.500000
# 60845 2023-02-02 15:56:22+00:00  314.066864  302.550476    0.160000
#
#              frp  ...  satellite                              algorithm  \
# 0       0.933132  ...  SUOMI-NPP              VIIRS-Active-Fire-Product
# 1       4.064853  ...    NOAA-20                                   OT-S
# 2       2.574483  ...    NOAA-20                                   OT-S
# 3       2.369543  ...    NOAA-20              VIIRS-Active-Fire-Product
# 4       3.982046  ...    NOAA-20              VIIRS-Active-Fire-Product
# ...          ...  ...        ...                                    ...
# 60841  11.441710  ...    NOAA-20              VIIRS-Active-Fire-Product
# 60842  11.441710  ...    NOAA-20              VIIRS-Active-Fire-Product
# 60843  13.985281  ...    NOAA-20              VIIRS-Active-Fire-Product
# 60844  13.985281  ...    NOAA-20              VIIRS-Active-Fire-Product
# 60845   5.259470  ...      TERRA  MODIS-Collection6-Active-Fire-Product
#
#        mir_bt_avg  tir_bt_avg mir_threshold  tir_threshold  delta_bt_avg  \
# 0             NaN         NaN           NaN            NaN           NaN
# 1      281.463673  283.431368         290.0     280.431368     -1.967695
# 2      281.463673  283.431368         290.0     280.431368     -1.967695
# 3             NaN         NaN           NaN            NaN           NaN
# 4             NaN         NaN           NaN            NaN           NaN
# ...           ...         ...           ...            ...           ...
# 60841         NaN         NaN           NaN            NaN           NaN
# 60842         NaN         NaN           NaN            NaN           NaN
# 60843         NaN         NaN           NaN            NaN           NaN
# 60844         NaN         NaN           NaN            NaN           NaN
# 60845         NaN         NaN           NaN            NaN           NaN
#
#        frp_uncertainty  delta_bt_thr  hotspot_class
# 0                  NaN           NaN            NaN
# 1             0.792725           NaN            NaN
# 2             0.613863           NaN            NaN
# 3                  NaN           NaN            NaN
# 4                  NaN           NaN            NaN
# ...                ...           ...            ...
# 60841              NaN           NaN            NaN
# 60842              NaN           NaN            NaN
# 60843              NaN           NaN            NaN
# 60844              NaN           NaN            NaN
# 60845              NaN           NaN            NaN
#
# [60846 rows x 23 columns]

# %%
hotspot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60846 entries, 0 to 60845
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                60846 non-null  int64
#  1   lat               60846 non-null  float64
#  2   lon               60846 non-null  float64
#  3   gsd               60846 non-null  float64
#  4   acquisition_time  60846 non-null  datetime64[ns, UTC]
#  5   detection_time    60846 non-null  datetime64[ns, UTC]
#  6   mir_bt            28200 non-null  float64
#  7   tir_bt            27009 non-null  float64
#  8   confidence        60808 non-null  float64
#  9   frp               45863 non-null  float64
#  10  normalized_frp    45863 non-null  float64
#  11  landuse_class     60846 non-null  int64
#  12  product_id        60846 non-null  int64
#  13  satellite         60846 non-null  object
#  14  algorithm         60846 non-null  object
#  15  mir_bt_avg        5904 non-null   float64
#  16  tir_bt_avg        5904 non-null   float64
#  17  mir_threshold     5904 non-null   float64
#  18  tir_threshold     5904 non-null   float64
#  19  delta_bt_avg      5904 non-null   float64
#  20  frp_uncertainty   33430 non-null  float64
#  21  delta_bt_thr      1515 non-null   float64
#  22  hotspot_class     1191 non-null   float64
# dtypes: datetime64[ns, UTC](2), float64(16), int64(3), object(2)
# memory usage: 10.7+ MB

# %%
hotspot = hotspot[hotspot['mir_bt'].notna()]
hotspot = hotspot[hotspot['frp'].notna()]
hotspot
# Out:
#               id        lat        lon     gsd          acquisition_time  \
# 0      340503774 -37.573338 -72.809982   375.0 2023-02-20 06:24:06+00:00
# 1      340482670 -37.574661 -72.804817   750.0 2023-02-20 05:32:20+00:00
# 2      340482669 -37.572521 -72.815674   750.0 2023-02-20 05:32:20+00:00
# 3      340482981 -37.574902 -72.813324   375.0 2023-02-20 05:32:09+00:00
# 4      340482980 -37.575958 -72.807961   375.0 2023-02-20 05:32:09+00:00
# ...          ...        ...        ...     ...                       ...
# 60841  335107255 -37.501709 -72.593956   375.0 2023-02-02 18:30:02+00:00
# 60842  335107257 -37.498184 -72.594635   375.0 2023-02-02 18:30:02+00:00
# 60843  335107254 -37.501087 -72.589027   375.0 2023-02-02 18:30:02+00:00
# 60844  335107256 -37.497562 -72.589722   375.0 2023-02-02 18:30:02+00:00
# 60845  335014392 -37.173077 -72.943893  1000.0 2023-02-02 14:43:13+00:00
#
#                  detection_time      mir_bt      tir_bt  confidence  \
# 0     2023-02-20 11:14:14+00:00  300.264648  286.906799    0.500000
# 1     2023-02-20 07:15:37+00:00  295.815796  287.405548    0.650321
# 2     2023-02-20 07:15:37+00:00  291.642822  287.766937    0.505038
# 3     2023-02-20 07:16:58+00:00  304.782867  287.029938    0.500000
# 4     2023-02-20 07:16:58+00:00  327.564240  288.805969    0.500000
# ...                         ...         ...         ...         ...
# 60841 2023-02-02 20:23:03+00:00  333.399139  308.330200    0.500000
# 60842 2023-02-02 20:23:03+00:00  301.725189  311.209747    0.250000
# 60843 2023-02-02 20:23:03+00:00  336.259949  311.073761    0.500000
# 60844 2023-02-02 20:23:03+00:00  336.952362  310.423584    0.500000
# 60845 2023-02-02 15:56:22+00:00  314.066864  302.550476    0.160000
#
#              frp  ...  satellite                              algorithm  \
# 0       0.933132  ...  SUOMI-NPP              VIIRS-Active-Fire-Product
# 1       4.064853  ...    NOAA-20                                   OT-S
# 2       2.574483  ...    NOAA-20                                   OT-S
# 3       2.369543  ...    NOAA-20              VIIRS-Active-Fire-Product
# 4       3.982046  ...    NOAA-20              VIIRS-Active-Fire-Product
# ...          ...  ...        ...                                    ...
# 60841  11.441710  ...    NOAA-20              VIIRS-Active-Fire-Product
# 60842  11.441710  ...    NOAA-20              VIIRS-Active-Fire-Product
# 60843  13.985281  ...    NOAA-20              VIIRS-Active-Fire-Product
# 60844  13.985281  ...    NOAA-20              VIIRS-Active-Fire-Product
# 60845   5.259470  ...      TERRA  MODIS-Collection6-Active-Fire-Product
#
#        mir_bt_avg  tir_bt_avg mir_threshold  tir_threshold  delta_bt_avg  \
# 0             NaN         NaN           NaN            NaN           NaN
# 1      281.463673  283.431368         290.0     280.431368     -1.967695
# 2      281.463673  283.431368         290.0     280.431368     -1.967695
# 3             NaN         NaN           NaN            NaN           NaN
# 4             NaN         NaN           NaN            NaN           NaN
# ...           ...         ...           ...            ...           ...
# 60841         NaN         NaN           NaN            NaN           NaN
# 60842         NaN         NaN           NaN            NaN           NaN
# 60843         NaN         NaN           NaN            NaN           NaN
# 60844         NaN         NaN           NaN            NaN           NaN
# 60845         NaN         NaN           NaN            NaN           NaN
#
#        frp_uncertainty  delta_bt_thr  hotspot_class
# 0                  NaN           NaN            NaN
# 1             0.792725           NaN            NaN
# 2             0.613863           NaN            NaN
# 3                  NaN           NaN            NaN
# 4                  NaN           NaN            NaN
# ...                ...           ...            ...
# 60841              NaN           NaN            NaN
# 60842              NaN           NaN            NaN
# 60843              NaN           NaN            NaN
# 60844              NaN           NaN            NaN
# 60845              NaN           NaN            NaN
#
# [28118 rows x 23 columns]

# %% [markdown]
# After renaming the variable of the dataframe, we use .describe() to see essential statistics for each variable

# %%
hotspot.describe()
# Out:
#                  id           lat           lon           gsd        mir_bt  \
# count  2.811800e+04  28118.000000  28118.000000  28118.000000  28118.000000
# mean   3.359271e+08    -37.449579    -72.809240    634.844228    337.598103
# std    7.175084e+05      0.166218      0.120382    283.329244     29.952898
# min    3.350144e+08    -37.758617    -73.131378    375.000000    207.934128
# 25%    3.354360e+08    -37.585278    -72.865713    375.000000    315.360420
# 50%    3.355023e+08    -37.445528    -72.785496    375.000000    334.224213
# 75%    3.363531e+08    -37.323350    -72.716370   1000.000000    351.780350
# max    3.405038e+08    -37.060635    -72.556319   1100.000000    610.989502
#
#              tir_bt    confidence           frp  normalized_frp  \
# count  26927.000000  28118.000000  28118.000000    28118.000000
# mean     302.747825      0.664832     71.561628      182.985593
# std       13.074077      0.252892    229.270159      431.784404
# min      267.489742      0.000000      0.146357        0.941960
# 25%      293.774689      0.500000      6.457025       21.383465
# 50%      300.076371      0.505603     18.109147       52.720927
# 75%      306.986359      0.936748     50.862084      156.711977
# max      400.068268      1.000000   8336.817383     9989.883250
#
#        landuse_class    product_id   mir_bt_avg   tir_bt_avg  mir_threshold  \
# count   28118.000000  2.811800e+04  5904.000000  5904.000000    5904.000000
# mean      511.837257  7.149870e+06   290.947706   292.199825     293.374227
# std         7.256834  1.969927e+04     7.649316     7.395392       6.031235
# min       510.000000  7.123717e+06   275.224376   278.323241     290.000000
# 25%       510.000000  7.136724e+06   285.765898   287.221816     290.000000
# 50%       510.000000  7.138241e+06   288.730899   289.405695     290.000000
# 75%       510.000000  7.163736e+06   293.684754   293.112953     293.684754
# max       580.000000  7.274698e+06   312.399391   313.556397     312.399391
#
#        tir_threshold  delta_bt_avg  frp_uncertainty  delta_bt_thr  \
# count    5904.000000   5904.000000     11675.000000   1515.000000
# mean      289.119207     -1.252119        14.450758      1.443389
# std         7.668099      1.593849        35.580892      2.203225
# min       270.000000     -5.781295         0.212158      0.004307
# 25%       284.000188     -2.297391         2.465708      0.545929
# 50%       286.405695     -0.695115         4.894977      1.178048
# 75%       290.112953      0.001436        12.148007      1.715404
# max       310.556397      2.751480       843.257198     15.000000
#
#        hotspot_class
# count         1191.0
# mean             1.0
# std              0.0
# min              1.0
# 25%              1.0
# 50%              1.0
# 75%              1.0
# max              1.0

# %% [markdown]
# We now make scatterplots for a number of variables

# %%
pd.plotting.scatter_matrix(hotspot[['mir_bt', 'tir_bt', 'frp','frp_uncertainty','confidence']]);

# %%
latitudes = hotspot['lat'].unique()
longitudes = hotspot['lon'].unique()

# %%
hotspot['satellite'].unique()
# Out:
# array(['SUOMI-NPP', 'NOAA-20', 'MetOp-C', 'AQUA', 'MetOp-B', 'TERRA',
#        'SENTINEL-3B', 'SENTINEL-3A'], dtype=object)

# %%
fig, ax = pl.subplots(figsize=(14, 4)) 
hotspot.boxplot('confidence', by='satellite', ax=ax);

# %%
X = hotspot[['mir_bt']]
Y = hotspot[['frp']]

# %%
reg = LinearRegression().fit(X, Y)

# %%
reg.coef_
# Out:
# array([[4.68961413]])

# %%
reg.intercept_
# Out:
# array([-1511.6432085])

# %%
y_pred = reg.predict(X)

# %%
fig, ax = pl.subplots(figsize=(4, 4)) 
ax = pl.scatter(X, Y, color = 'k', s=1)
ax = pl.plot(X, reg.predict(X), color = 'blue')
