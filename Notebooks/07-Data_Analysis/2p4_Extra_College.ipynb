# %% [markdown]
# # College.csv Dataset Extra Analysis

# %% [markdown]
# This exercise relates to the College data set, which can be found in the file College.csv on the book website. It contains a number of variables for 777 different universities and colleges in the US.

# %% [markdown]
# We perform two extra analysis:
#
# - Enrollment Success
# - Public/Private Expenses

# %% [markdown]
# Libraries we need are imported first

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl

# %% [markdown]
# Data used in this exercise is stored in the DATA folder

# %%
data_path = '../../DATA/college.csv'

# %% [markdown]
# The dataframe is created using the .read_csv function of Pandas

# %%
college = pd.read_csv(data_path)

# %% [markdown]
# The original CSV file is structured as a dataframe with the corresponding categories

# %%
college3 = college.rename({'Unnamed: 0': 'College'}, axis=1)

# %%
college3 = college3.set_index('College')

# %%
college3
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University           52         2885          537      7440
# Adelphi University                     29         2683         1227     12280
# Adrian College                         50         1036           99     11250
# Agnes Scott College                    89          510           63     12960
# Alaska Pacific University              44          249          869      7560
# ...                                   ...          ...          ...       ...
# Worcester State College                26         3089         2029      6797
# Xavier University                      47         2849         1107     11520
# Xavier University of Louisiana         61         2793          166      6900
# Yale University                        99         5217           83     19840
# York College of Pennsylvania           63         2988         1726      4990
#
#                                 Room.Board  Books  Personal  PhD  Terminal  \
# College
# Abilene Christian University          3300    450      2200   70        78
# Adelphi University                    6450    750      1500   29        30
# Adrian College                        3750    400      1165   53        66
# Agnes Scott College                   5450    450       875   92        97
# Alaska Pacific University             4120    800      1500   76        72
# ...                                    ...    ...       ...  ...       ...
# Worcester State College               3900    500      1200   60        60
# Xavier University                     4960    600      1250   73        75
# Xavier University of Louisiana        4200    617       781   67        75
# Yale University                       6510    630      2115   96        96
# York College of Pennsylvania          3560    500      1250   75        75
#
#                                 S.F.Ratio  perc.alumni  Expend  Grad.Rate
# College
# Abilene Christian University         18.1           12    7041         60
# Adelphi University                   12.2           16   10527         56
# Adrian College                       12.9           30    8735         54
# Agnes Scott College                   7.7           37   19016         59
# Alaska Pacific University            11.9            2   10922         15
# ...                                   ...          ...     ...        ...
# Worcester State College              21.0           14    4469         40
# Xavier University                    13.3           31    9189         83
# Xavier University of Louisiana       14.4           20    8323         49
# Yale University                       5.8           49   40386         99
# York College of Pennsylvania         18.1           28    4509         99
#
# [777 rows x 18 columns]

# %% [markdown]
# ## Enrollment Success

# %% [markdown]
# We address the question of which of these universities have the higher ratio of enrollment compared to the total number of applications. To this end, we calculate the ratio of enrollment vs applications, we calculate essential statistics and we plot the results.

# %% [markdown]
# We first remove the columns we do not use for clarity purposes

# %%
college.drop(['Top10perc', 'Top25perc', 'F.Undergrad','P.Undergrad','Outstate','Room.Board','Books','Personal','PhD','Terminal','S.F.Ratio','perc.alumni','Expend','Grad.Rate'], axis=1, inplace=True)

# %% [markdown]
# We now calculate the ratio of enrollment versus total number of applications

# %%
college['ratio'] = college['Enroll']/college['Apps']
college = college.rename({'Unnamed: 0': 'College'}, axis=1)
college
# Out:
#      index                                  College Private  Apps  Accept  \
# 0      484       Rutgers State University at Camden      No  3366    1752
# 1      578                        Talladega College     Yes  4414    1500
# 2      570                SUNY College at New Paltz      No  8399    3609
# 3      210                  Franklin Pierce College     Yes  5187    4471
# 4      485       Rutgers State University at Newark      No  5785    2690
# ..     ...                                      ...     ...   ...     ...
# 772    672  University of Sci. and Arts of Oklahoma      No   285     280
# 773    165               Dickinson State University      No   434     412
# 774    247                Hardin-Simmons University     Yes   467     424
# 775    376         Mississippi University for Women      No   480     405
# 776     66                   Brewton-Parker College     Yes  1436    1228
#
#      Enroll     ratio
# 0       232  0.068925
# 1       335  0.075895
# 2       656  0.078105
# 3       446  0.085984
# 4       499  0.086258
# ..      ...       ...
# 772     208  0.729825
# 773     319  0.735023
# 774     350  0.749465
# 775     380  0.791667
# 776    1202  0.837047
#
# [777 rows x 7 columns]

# %%
college = college.sort_values('ratio',ascending=True)
college = college.reset_index()
college
# Out:
#      level_0  index                                  College Private  Apps  \
# 0          0    484       Rutgers State University at Camden      No  3366
# 1          1    578                        Talladega College     Yes  4414
# 2          2    570                SUNY College at New Paltz      No  8399
# 3          3    210                  Franklin Pierce College     Yes  5187
# 4          4    485       Rutgers State University at Newark      No  5785
# ..       ...    ...                                      ...     ...   ...
# 772      772    672  University of Sci. and Arts of Oklahoma      No   285
# 773      773    165               Dickinson State University      No   434
# 774      774    247                Hardin-Simmons University     Yes   467
# 775      775    376         Mississippi University for Women      No   480
# 776      776     66                   Brewton-Parker College     Yes  1436
#
#      Accept  Enroll     ratio
# 0      1752     232  0.068925
# 1      1500     335  0.075895
# 2      3609     656  0.078105
# 3      4471     446  0.085984
# 4      2690     499  0.086258
# ..      ...     ...       ...
# 772     280     208  0.729825
# 773     412     319  0.735023
# 774     424     350  0.749465
# 775     405     380  0.791667
# 776    1228    1202  0.837047
#
# [777 rows x 8 columns]

# %%
college.describe()
# Out:
#           level_0       index          Apps        Accept       Enroll  \
# count  777.000000  777.000000    777.000000    777.000000   777.000000
# mean   388.000000  388.000000   3001.638353   2018.804376   779.972973
# std    224.444871  224.444871   3870.201484   2451.113971   929.176190
# min      0.000000    0.000000     81.000000     72.000000    35.000000
# 25%    194.000000  194.000000    776.000000    604.000000   242.000000
# 50%    388.000000  388.000000   1558.000000   1110.000000   434.000000
# 75%    582.000000  582.000000   3624.000000   2424.000000   902.000000
# max    776.000000  776.000000  48094.000000  26330.000000  6392.000000
#
#             ratio
# count  777.000000
# mean     0.309368
# std      0.123881
# min      0.068925
# 25%      0.220107
# 50%      0.291521
# 75%      0.382682
# max      0.837047

# %%
college.plot(y='ratio', use_index=True)
# Out:
# <Axes: >

# %%
college_public = college[college['Private'].str.contains('No')==True]
college_public = college_public.iloc[0:200].reset_index(drop=True)
college_public
# Out:
#      level_0  index                                  College Private   Apps  \
# 0          0    484       Rutgers State University at Camden      No   3366
# 1          2    570                SUNY College at New Paltz      No   8399
# 2          4    485       Rutgers State University at Newark      No   5785
# 3          6    483                 Rutgers at New Brunswick      No  48094
# 4         16    561                       SUNY at Binghamton      No  14463
# ..       ...    ...                                      ...     ...    ...
# 195      747    381  Montana College of Mineral Sci. & Tech.      No    572
# 196      748    647        University of Nebraska at Lincoln      No   6277
# 197      749    363                       Mesa State College      No   1584
# 198      750    706             Valley City State University      No    368
# 199      751    377          Missouri Southern State College      No   1576
#
#      Accept  Enroll     ratio
# 0      1752     232  0.068925
# 1      3609     656  0.078105
# 2      2690     499  0.086258
# 3     26330    4520  0.093983
# 4      6166    1757  0.121482
# ..      ...     ...       ...
# 195     544     320  0.559441
# 196    6003    3526  0.561733
# 197    1456     891  0.562500
# 198     344     212  0.576087
# 199    1326     913  0.579315
#
# [200 rows x 8 columns]

# %%
college_private = college[college['Private'].str.contains('Yes')==True]
college_private = college_private.iloc[0:200].reset_index(drop=True)
college_private
# Out:
#      level_0  index                          College Private   Apps  Accept  \
# 0          1    578                Talladega College     Yes   4414    1500
# 1          3    210          Franklin Pierce College     Yes   5187    4471
# 2          5    459             Princeton University     Yes  13218    2042
# 3          7     16                  Amherst College     Yes   4302     992
# 4          8    323                Louisiana College     Yes   2013    1053
# ..       ...    ...                              ...     ...    ...     ...
# 195      247    665           University of Portland     Yes   1758    1485
# 196      250    199                  Flagler College     Yes   1415     714
# 197      251    335                MacMurray College     Yes    740     558
# 198      252    753           Westminster College PA     Yes   1738    1373
# 199      253    413  North Carolina Wesleyan College     Yes    812     689
#
#      Enroll     ratio
# 0       335  0.075895
# 1       446  0.085984
# 2      1153  0.087230
# 3       418  0.097164
# 4       212  0.105315
# ..      ...       ...
# 195     419  0.238339
# 196     338  0.238869
# 197     177  0.239189
# 198     417  0.239931
# 199     195  0.240148
#
# [200 rows x 8 columns]

# %%
fig, ax = pl.subplots(figsize=(10, 4)) 
ax = college_public.plot(ax=ax, y='ratio', use_index=True, label='Public')
college_private.plot(ax=ax, y='ratio', use_index=True, label='Private')
# Out:
# <Axes: >
