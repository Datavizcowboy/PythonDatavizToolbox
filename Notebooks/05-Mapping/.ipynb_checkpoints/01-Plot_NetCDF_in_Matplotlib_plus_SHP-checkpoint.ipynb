# %% [markdown]
# # Read a NetCDF file, plot it in Matplotlib and overlay an SHP area

# %% [markdown]
# In this notebook we open a NetCDF file, we assign variables to the coordinates and values, we plot the values using matplotlib with some layout choices and we finally plot on top an SHP contour line.

# %% [markdown]
# We first load useful libraries

# %%
from netCDF4 import Dataset
import matplotlib.pyplot as plt
from matplotlib.ticker import EngFormatter, StrMethodFormatter
import geopandas as gp

# %% [markdown]
# We open the global wind speed dataset in NetCDF format

# %%
data = Dataset('../../DATA/wind.nc','r')

# %% [markdown]
# We assign the coordinates to variables as well as the wind speed values

# %%
lons = data.variables['FNOCXN79_64'][:]
lats = data.variables['FNOCY'][:]
unwd = data.variables['UWND'][0,:,:]
data.close()

# %% [markdown]
# In parallel, we open the SHP file as a geopandas dataframe and we define the boundaries that will define the plot area

# %%
df = gp.read_file('../../DATA/cb_2018_us_nation_20m.shp')
x_min, y_min, x_max, y_max = df.total_bounds

# %% [markdown]
# The plot includes the wind speed values and the contour of the United States

# %%
fig,ax = plt.subplots(dpi=144)

ax.set_ylim(y_min,y_max)
ax.set_xlim(x_min,-50)

ax.set_xlabel('Longitude', fontsize=6,linespacing=1, color='grey')
ax.set_ylabel('Latitude', fontsize=6, color='grey')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('grey')
ax.spines['left'].set_color('grey')

ax.text(0.75,0.90,'X-component',fontsize=7,weight='bold',color='white',transform=ax.transAxes, bbox=dict(facecolor='none',edgecolor='none',boxstyle='square')) 
ax.text(0.75,0.85,'(m/s)',fontsize=6,color='white',transform=ax.transAxes, bbox=dict(facecolor='none',edgecolor='none',boxstyle='square')) 

ax.minorticks_on()
ax.tick_params(axis='both', which='major', labelsize=4, colors='grey')
ax.tick_params(axis='both', which='minor', labelsize=4, colors='grey')

ax.yaxis.set_major_formatter(EngFormatter(unit=u"°N"))
ax.xaxis.set_major_formatter(EngFormatter(unit=u"°W"))

mesh = ax.pcolormesh(lons,lats,unwd);
df.plot(ax=ax, facecolor='none',edgecolor='white',linewidth=0.5);

cbar = plt.colorbar(mesh, ax=ax, shrink=.5, pad=.02, aspect=10)
cbar.ax.tick_params(labelsize=5, width=0.1) 

ax.grid(linestyle='dotted',linewidth=.8, alpha=0.5, color='gray')
