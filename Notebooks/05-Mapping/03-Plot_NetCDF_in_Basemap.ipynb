# %% [markdown]
# # Plot NetCDF in Basemap

# %% [markdown]
# We first load useful libraries

# %%
from netCDF4 import Dataset
import numpy as np
import pylab as pl
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/5k/mjzbrl8j1773drpygwd3n0mm0000gn/T/ipykernel_37168/4051154943.py in <cell line: 4>()
#       2 import numpy as np
#       3 import pylab as pl
# ----> 4 from mpl_toolkits.basemap import Basemap
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %% [markdown]
# We then generate some random numbers

# %%
data = Dataset('../../DATA/wind.nc','r')

# %% [markdown]
# We then extract the coordinates and variables

# %%
lons = data.variables['FNOCXN79_64'][:]
lats = data.variables['FNOCY'][:]
unwd = data.variables['UWND'][0,:,:]
data.close()

# %% [markdown]
# We create the plot

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
plt.contourf(lons, lats, unwd.data, 10,
             transform=ccrs.PlateCarree())
ax.coastlines()
plt.title('X-component of Wind Speed')
plt.show()
