# %% [markdown]
# # Pandas Numerical Cleaning and Filtering

# %% [markdown]
# In this notebook we first read a JSON file with volcano eruption data, we convert it into a Pandas dataframe and then we perform different pandas commands and utilities to filter the data and to calculate additional metrics based on the existing column values.

# %% [markdown]
# Libraries we need are imported first

# %%
import numpy as np
import pandas as pd
import json
import datetime
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Data used in this exercise is from the volcanic loss metrics database available in the DATA folder as a JSON file

# %%
data_path = '../../DATA/volcanic-eruption-database.json'

# %% [markdown]
# The dataframe is created using the load( ) function from the JSON python library

# %%
with open(data_path) as f:
    data = json.load(f)

# %% [markdown]
# We now assign different fields of interest to the dataframe, particularly the date and the loss associated with each eruption

# %%
content = pd.DataFrame()
content['year']=list(map(lambda data: data['year'], data))
content['month']=list(map(lambda data: data['month'], data))
content['day']=list(map(lambda data: data['day'], data))
content['name']=list(map(lambda data: data['name'], data))
content['country']=list(map(lambda data: data['country'], data))
content['loss']=list(map(lambda data: data['total_damage_millions_dollars'], data))
content
# Out:
#      year month day             name           country    loss
# 0    2010    07  03        Stromboli             Italy       5
# 1    2010    03  25            Bromo         Indonesia    5.55
# 2    2010    03  25       Tunguruhua         Indonesia  160.22
# 3    1982    03  25       Galanggung         Indonesia     100
# 4    1990    03  19          Kilauea     United States   100.5
# ..    ...   ...  ..              ...               ...     ...
# 843  2006    05  20  Soufriere Hills        Montserrat    None
# 844  2015    04  22          Calbuco             Chile    None
# 845  2017    09  12    Campi Flegrei             Italy    None
# 846  2018    01  05          Kadovar  Papua New Guinea    None
# 847  2018    03  21             Ijen         Indonesia    None
#
# [848 rows x 6 columns]

# %% [markdown]
# The original CSV file is now structured as a dataframe with the corresponding categories. Now the first filter we apply will be the actual existing values for loss, removing those labelled with "None" that are those corresponding to 'Nan'. Pandas does this using the .dropna( ) function

# %%
content= content.dropna()
content
# Out:
#      year month day                       name                       country  \
# 0    2010    07  03                  Stromboli                         Italy
# 1    2010    03  25                      Bromo                     Indonesia
# 2    2010    03  25                 Tunguruhua                     Indonesia
# 3    1982    03  25                 Galanggung                     Indonesia
# 4    1990    03  19                    Kilauea                 United States
# 5    1960    03  19                    Kilauea                 United States
# 6    2021    03  13      Soufriere St. Vincent  St. Vincent & the Grenadines
# 7    1976    03  13      Soufriere St. Vincent  St. Vincent & the Grenadines
# 8    2021    05  05               Cumbre Vieja                         Spain
# 9    1955    04  19                    Kilauea                 United States
# 10   2022    03  30  Hunga Tonga-Hunga Ha'apai                         Tonga
# 11   1995    04  27      Soufriere St. Vincent  St. Vincent & the Grenadines
# 34   2018    12  26                       Etna                         Italy
# 35   2020    01  12                       Taal                   Philippines
# 84   1902    05  07      Soufriere St. Vincent  St. Vincent & the Grenadines
# 129  2018    12  22                   Krakatau                     Indonesia
# 130  2019    06  26                     Ulawun              Papua New Guinea
# 147  1992    04  10               Negro, Cerro                     Nicaragua
# 180  2018    02  01                    Kilauea                 United States
# 204  1994    06  06                      Huila                      Colombia
# 218  1902    05  08                      Pelee                    Martinique
# 226  1973    01  27             Vestmannaeyjar                       Iceland
# 228  1975    11  29                    Kilauea                 United States
# 318  1902    10  25                Santa Maria                     Guatemala
# 322  1951    01  21                  Lamington              Papua New Guinea
# 371  2018    04  28                    Kilauea                 United States
# 403  2016    05  21                   Sinabung                     Indonesia
# 416  1914    01  12                Sakura-jima                         Japan
# 458  1994    09  19                     Rabaul              Papua New Guinea
# 510  1987    12  01                     Sirung                     Indonesia
# 514  2010    08  30                   Sinabung                     Indonesia
# 536  1992    09  17                      Spurr                 United States
# 540  2010    05  27                     Pacaya                     Guatemala
# 541  2010    10  26                     Merapi                     Indonesia
# 545  2018    07  16                    Kilauea                 United States
# 565  1980    05  18                 St. Helens                 United States
# 567  1985    11  13                       Ruiz                      Colombia
# 572  2010    03  31           Eyjafjallajokull                       Iceland
# 599  2018    06  03                      Fuego                     Guatemala
# 669  2002    01  17                 Nyiragongo                    Congo, DRC
# 701  1982    03  29                Chichon, El                        Mexico
# 709  2018    01  13                      Mayon                   Philippines
# 753  1979    04  13      Soufriere St. Vincent  St. Vincent & the Grenadines
# 757  1991    12  14                       Etna                         Italy
# 786  1982    05  17                 Galunggung                     Indonesia
# 818  2014    11  10                    Kilauea                 United States
# 837  1991    06  15                   Pinatubo                   Philippines
#
#        loss
# 0         5
# 1      5.55
# 2    160.22
# 3       100
# 4     100.5
# 5         6
# 6       400
# 7      1000
# 8       906
# 9      2.59
# 10       90
# 11      500
# 34      115
# 35       67
# 84      200
# 129     250
# 130      14
# 147       3
# 180     536
# 204     2.4
# 218    1000
# 226     200
# 228       4
# 318      15
# 322      10
# 371     370
# 403     100
# 416      19
# 458      86
# 510       5
# 514    3295
# 536       2
# 540  68.385
# 541     890
# 545       1
# 565    2000
# 567    1000
# 572    5000
# 599     120
# 669       9
# 701     3.3
# 709   3.564
# 753     100
# 757     2.5
# 786      15
# 818    14.5
# 837     750

# %% [markdown]
# We have now a subgroup of volcano eruptions for which we have loss data available. The next step is to create a valid timestamp combining the day, month and year values as follows:

# %%
content['date'] = pd.to_datetime(content[['year', 'month', 'day']])
content.drop(['year', 'month', 'day'], axis=1, inplace=True)
content
# Out:
#                           name                       country    loss  \
# 0                    Stromboli                         Italy       5
# 1                        Bromo                     Indonesia    5.55
# 2                   Tunguruhua                     Indonesia  160.22
# 3                   Galanggung                     Indonesia     100
# 4                      Kilauea                 United States   100.5
# 5                      Kilauea                 United States       6
# 6        Soufriere St. Vincent  St. Vincent & the Grenadines     400
# 7        Soufriere St. Vincent  St. Vincent & the Grenadines    1000
# 8                 Cumbre Vieja                         Spain     906
# 9                      Kilauea                 United States    2.59
# 10   Hunga Tonga-Hunga Ha'apai                         Tonga      90
# 11       Soufriere St. Vincent  St. Vincent & the Grenadines     500
# 34                        Etna                         Italy     115
# 35                        Taal                   Philippines      67
# 84       Soufriere St. Vincent  St. Vincent & the Grenadines     200
# 129                   Krakatau                     Indonesia     250
# 130                     Ulawun              Papua New Guinea      14
# 147               Negro, Cerro                     Nicaragua       3
# 180                    Kilauea                 United States     536
# 204                      Huila                      Colombia     2.4
# 218                      Pelee                    Martinique    1000
# 226             Vestmannaeyjar                       Iceland     200
# 228                    Kilauea                 United States       4
# 318                Santa Maria                     Guatemala      15
# 322                  Lamington              Papua New Guinea      10
# 371                    Kilauea                 United States     370
# 403                   Sinabung                     Indonesia     100
# 416                Sakura-jima                         Japan      19
# 458                     Rabaul              Papua New Guinea      86
# 510                     Sirung                     Indonesia       5
# 514                   Sinabung                     Indonesia    3295
# 536                      Spurr                 United States       2
# 540                     Pacaya                     Guatemala  68.385
# 541                     Merapi                     Indonesia     890
# 545                    Kilauea                 United States       1
# 565                 St. Helens                 United States    2000
# 567                       Ruiz                      Colombia    1000
# 572           Eyjafjallajokull                       Iceland    5000
# 599                      Fuego                     Guatemala     120
# 669                 Nyiragongo                    Congo, DRC       9
# 701                Chichon, El                        Mexico     3.3
# 709                      Mayon                   Philippines   3.564
# 753      Soufriere St. Vincent  St. Vincent & the Grenadines     100
# 757                       Etna                         Italy     2.5
# 786                 Galunggung                     Indonesia      15
# 818                    Kilauea                 United States    14.5
# 837                   Pinatubo                   Philippines     750
#
#           date
# 0   2010-07-03
# 1   2010-03-25
# 2   2010-03-25
# 3   1982-03-25
# 4   1990-03-19
# 5   1960-03-19
# 6   2021-03-13
# 7   1976-03-13
# 8   2021-05-05
# 9   1955-04-19
# 10  2022-03-30
# 11  1995-04-27
# 34  2018-12-26
# 35  2020-01-12
# 84  1902-05-07
# 129 2018-12-22
# 130 2019-06-26
# 147 1992-04-10
# 180 2018-02-01
# 204 1994-06-06
# 218 1902-05-08
# 226 1973-01-27
# 228 1975-11-29
# 318 1902-10-25
# 322 1951-01-21
# 371 2018-04-28
# 403 2016-05-21
# 416 1914-01-12
# 458 1994-09-19
# 510 1987-12-01
# 514 2010-08-30
# 536 1992-09-17
# 540 2010-05-27
# 541 2010-10-26
# 545 2018-07-16
# 565 1980-05-18
# 567 1985-11-13
# 572 2010-03-31
# 599 2018-06-03
# 669 2002-01-17
# 701 1982-03-29
# 709 2018-01-13
# 753 1979-04-13
# 757 1991-12-14
# 786 1982-05-17
# 818 2014-11-10
# 837 1991-06-15

# %% [markdown]
# We now make the loss field uniform in format by converting to numeric all values displayed

# %%
content['loss'] = pd.to_numeric(content['loss'])
content
# Out:
#                           name                       country      loss  \
# 0                    Stromboli                         Italy     5.000
# 1                        Bromo                     Indonesia     5.550
# 2                   Tunguruhua                     Indonesia   160.220
# 3                   Galanggung                     Indonesia   100.000
# 4                      Kilauea                 United States   100.500
# 5                      Kilauea                 United States     6.000
# 6        Soufriere St. Vincent  St. Vincent & the Grenadines   400.000
# 7        Soufriere St. Vincent  St. Vincent & the Grenadines  1000.000
# 8                 Cumbre Vieja                         Spain   906.000
# 9                      Kilauea                 United States     2.590
# 10   Hunga Tonga-Hunga Ha'apai                         Tonga    90.000
# 11       Soufriere St. Vincent  St. Vincent & the Grenadines   500.000
# 34                        Etna                         Italy   115.000
# 35                        Taal                   Philippines    67.000
# 84       Soufriere St. Vincent  St. Vincent & the Grenadines   200.000
# 129                   Krakatau                     Indonesia   250.000
# 130                     Ulawun              Papua New Guinea    14.000
# 147               Negro, Cerro                     Nicaragua     3.000
# 180                    Kilauea                 United States   536.000
# 204                      Huila                      Colombia     2.400
# 218                      Pelee                    Martinique  1000.000
# 226             Vestmannaeyjar                       Iceland   200.000
# 228                    Kilauea                 United States     4.000
# 318                Santa Maria                     Guatemala    15.000
# 322                  Lamington              Papua New Guinea    10.000
# 371                    Kilauea                 United States   370.000
# 403                   Sinabung                     Indonesia   100.000
# 416                Sakura-jima                         Japan    19.000
# 458                     Rabaul              Papua New Guinea    86.000
# 510                     Sirung                     Indonesia     5.000
# 514                   Sinabung                     Indonesia  3295.000
# 536                      Spurr                 United States     2.000
# 540                     Pacaya                     Guatemala    68.385
# 541                     Merapi                     Indonesia   890.000
# 545                    Kilauea                 United States     1.000
# 565                 St. Helens                 United States  2000.000
# 567                       Ruiz                      Colombia  1000.000
# 572           Eyjafjallajokull                       Iceland  5000.000
# 599                      Fuego                     Guatemala   120.000
# 669                 Nyiragongo                    Congo, DRC     9.000
# 701                Chichon, El                        Mexico     3.300
# 709                      Mayon                   Philippines     3.564
# 753      Soufriere St. Vincent  St. Vincent & the Grenadines   100.000
# 757                       Etna                         Italy     2.500
# 786                 Galunggung                     Indonesia    15.000
# 818                    Kilauea                 United States    14.500
# 837                   Pinatubo                   Philippines   750.000
#
#           date
# 0   2010-07-03
# 1   2010-03-25
# 2   2010-03-25
# 3   1982-03-25
# 4   1990-03-19
# 5   1960-03-19
# 6   2021-03-13
# 7   1976-03-13
# 8   2021-05-05
# 9   1955-04-19
# 10  2022-03-30
# 11  1995-04-27
# 34  2018-12-26
# 35  2020-01-12
# 84  1902-05-07
# 129 2018-12-22
# 130 2019-06-26
# 147 1992-04-10
# 180 2018-02-01
# 204 1994-06-06
# 218 1902-05-08
# 226 1973-01-27
# 228 1975-11-29
# 318 1902-10-25
# 322 1951-01-21
# 371 2018-04-28
# 403 2016-05-21
# 416 1914-01-12
# 458 1994-09-19
# 510 1987-12-01
# 514 2010-08-30
# 536 1992-09-17
# 540 2010-05-27
# 541 2010-10-26
# 545 2018-07-16
# 565 1980-05-18
# 567 1985-11-13
# 572 2010-03-31
# 599 2018-06-03
# 669 2002-01-17
# 701 1982-03-29
# 709 2018-01-13
# 753 1979-04-13
# 757 1991-12-14
# 786 1982-05-17
# 818 2014-11-10
# 837 1991-06-15

# %% [markdown]
# Once we have all dataframe fields in the correct format, we rank the order by date, from the oldest to the most recent volcano eruption

# %%
content = content.sort_values('date',ascending=True)
content = content.reset_index()
content.drop(['index'], axis=1, inplace=True)
content
# Out:
#                          name                       country      loss  \
# 0       Soufriere St. Vincent  St. Vincent & the Grenadines   200.000
# 1                       Pelee                    Martinique  1000.000
# 2                 Santa Maria                     Guatemala    15.000
# 3                 Sakura-jima                         Japan    19.000
# 4                   Lamington              Papua New Guinea    10.000
# 5                     Kilauea                 United States     2.590
# 6                     Kilauea                 United States     6.000
# 7              Vestmannaeyjar                       Iceland   200.000
# 8                     Kilauea                 United States     4.000
# 9       Soufriere St. Vincent  St. Vincent & the Grenadines  1000.000
# 10      Soufriere St. Vincent  St. Vincent & the Grenadines   100.000
# 11                 St. Helens                 United States  2000.000
# 12                 Galanggung                     Indonesia   100.000
# 13                Chichon, El                        Mexico     3.300
# 14                 Galunggung                     Indonesia    15.000
# 15                       Ruiz                      Colombia  1000.000
# 16                     Sirung                     Indonesia     5.000
# 17                    Kilauea                 United States   100.500
# 18                   Pinatubo                   Philippines   750.000
# 19                       Etna                         Italy     2.500
# 20               Negro, Cerro                     Nicaragua     3.000
# 21                      Spurr                 United States     2.000
# 22                      Huila                      Colombia     2.400
# 23                     Rabaul              Papua New Guinea    86.000
# 24      Soufriere St. Vincent  St. Vincent & the Grenadines   500.000
# 25                 Nyiragongo                    Congo, DRC     9.000
# 26                      Bromo                     Indonesia     5.550
# 27                 Tunguruhua                     Indonesia   160.220
# 28           Eyjafjallajokull                       Iceland  5000.000
# 29                     Pacaya                     Guatemala    68.385
# 30                  Stromboli                         Italy     5.000
# 31                   Sinabung                     Indonesia  3295.000
# 32                     Merapi                     Indonesia   890.000
# 33                    Kilauea                 United States    14.500
# 34                   Sinabung                     Indonesia   100.000
# 35                      Mayon                   Philippines     3.564
# 36                    Kilauea                 United States   536.000
# 37                    Kilauea                 United States   370.000
# 38                      Fuego                     Guatemala   120.000
# 39                    Kilauea                 United States     1.000
# 40                   Krakatau                     Indonesia   250.000
# 41                       Etna                         Italy   115.000
# 42                     Ulawun              Papua New Guinea    14.000
# 43                       Taal                   Philippines    67.000
# 44      Soufriere St. Vincent  St. Vincent & the Grenadines   400.000
# 45               Cumbre Vieja                         Spain   906.000
# 46  Hunga Tonga-Hunga Ha'apai                         Tonga    90.000
#
#          date
# 0  1902-05-07
# 1  1902-05-08
# 2  1902-10-25
# 3  1914-01-12
# 4  1951-01-21
# 5  1955-04-19
# 6  1960-03-19
# 7  1973-01-27
# 8  1975-11-29
# 9  1976-03-13
# 10 1979-04-13
# 11 1980-05-18
# 12 1982-03-25
# 13 1982-03-29
# 14 1982-05-17
# 15 1985-11-13
# 16 1987-12-01
# 17 1990-03-19
# 18 1991-06-15
# 19 1991-12-14
# 20 1992-04-10
# 21 1992-09-17
# 22 1994-06-06
# 23 1994-09-19
# 24 1995-04-27
# 25 2002-01-17
# 26 2010-03-25
# 27 2010-03-25
# 28 2010-03-31
# 29 2010-05-27
# 30 2010-07-03
# 31 2010-08-30
# 32 2010-10-26
# 33 2014-11-10
# 34 2016-05-21
# 35 2018-01-13
# 36 2018-02-01
# 37 2018-04-28
# 38 2018-06-03
# 39 2018-07-16
# 40 2018-12-22
# 41 2018-12-26
# 42 2019-06-26
# 43 2020-01-12
# 44 2021-03-13
# 45 2021-05-05
# 46 2022-03-30

# %% [markdown]
# We can now calculate the cumulative loss from the first record onwards with the .cumsum( ) function

# %%
content['loss_acc']=content['loss'].cumsum()
content
# Out:
#                          name                       country      loss  \
# 0       Soufriere St. Vincent  St. Vincent & the Grenadines   200.000
# 1                       Pelee                    Martinique  1000.000
# 2                 Santa Maria                     Guatemala    15.000
# 3                 Sakura-jima                         Japan    19.000
# 4                   Lamington              Papua New Guinea    10.000
# 5                     Kilauea                 United States     2.590
# 6                     Kilauea                 United States     6.000
# 7              Vestmannaeyjar                       Iceland   200.000
# 8                     Kilauea                 United States     4.000
# 9       Soufriere St. Vincent  St. Vincent & the Grenadines  1000.000
# 10      Soufriere St. Vincent  St. Vincent & the Grenadines   100.000
# 11                 St. Helens                 United States  2000.000
# 12                 Galanggung                     Indonesia   100.000
# 13                Chichon, El                        Mexico     3.300
# 14                 Galunggung                     Indonesia    15.000
# 15                       Ruiz                      Colombia  1000.000
# 16                     Sirung                     Indonesia     5.000
# 17                    Kilauea                 United States   100.500
# 18                   Pinatubo                   Philippines   750.000
# 19                       Etna                         Italy     2.500
# 20               Negro, Cerro                     Nicaragua     3.000
# 21                      Spurr                 United States     2.000
# 22                      Huila                      Colombia     2.400
# 23                     Rabaul              Papua New Guinea    86.000
# 24      Soufriere St. Vincent  St. Vincent & the Grenadines   500.000
# 25                 Nyiragongo                    Congo, DRC     9.000
# 26                      Bromo                     Indonesia     5.550
# 27                 Tunguruhua                     Indonesia   160.220
# 28           Eyjafjallajokull                       Iceland  5000.000
# 29                     Pacaya                     Guatemala    68.385
# 30                  Stromboli                         Italy     5.000
# 31                   Sinabung                     Indonesia  3295.000
# 32                     Merapi                     Indonesia   890.000
# 33                    Kilauea                 United States    14.500
# 34                   Sinabung                     Indonesia   100.000
# 35                      Mayon                   Philippines     3.564
# 36                    Kilauea                 United States   536.000
# 37                    Kilauea                 United States   370.000
# 38                      Fuego                     Guatemala   120.000
# 39                    Kilauea                 United States     1.000
# 40                   Krakatau                     Indonesia   250.000
# 41                       Etna                         Italy   115.000
# 42                     Ulawun              Papua New Guinea    14.000
# 43                       Taal                   Philippines    67.000
# 44      Soufriere St. Vincent  St. Vincent & the Grenadines   400.000
# 45               Cumbre Vieja                         Spain   906.000
# 46  Hunga Tonga-Hunga Ha'apai                         Tonga    90.000
#
#          date   loss_acc
# 0  1902-05-07    200.000
# 1  1902-05-08   1200.000
# 2  1902-10-25   1215.000
# 3  1914-01-12   1234.000
# 4  1951-01-21   1244.000
# 5  1955-04-19   1246.590
# 6  1960-03-19   1252.590
# 7  1973-01-27   1452.590
# 8  1975-11-29   1456.590
# 9  1976-03-13   2456.590
# 10 1979-04-13   2556.590
# 11 1980-05-18   4556.590
# 12 1982-03-25   4656.590
# 13 1982-03-29   4659.890
# 14 1982-05-17   4674.890
# 15 1985-11-13   5674.890
# 16 1987-12-01   5679.890
# 17 1990-03-19   5780.390
# 18 1991-06-15   6530.390
# 19 1991-12-14   6532.890
# 20 1992-04-10   6535.890
# 21 1992-09-17   6537.890
# 22 1994-06-06   6540.290
# 23 1994-09-19   6626.290
# 24 1995-04-27   7126.290
# 25 2002-01-17   7135.290
# 26 2010-03-25   7140.840
# 27 2010-03-25   7301.060
# 28 2010-03-31  12301.060
# 29 2010-05-27  12369.445
# 30 2010-07-03  12374.445
# 31 2010-08-30  15669.445
# 32 2010-10-26  16559.445
# 33 2014-11-10  16573.945
# 34 2016-05-21  16673.945
# 35 2018-01-13  16677.509
# 36 2018-02-01  17213.509
# 37 2018-04-28  17583.509
# 38 2018-06-03  17703.509
# 39 2018-07-16  17704.509
# 40 2018-12-22  17954.509
# 41 2018-12-26  18069.509
# 42 2019-06-26  18083.509
# 43 2020-01-12  18150.509
# 44 2021-03-13  18550.509
# 45 2021-05-05  19456.509
# 46 2022-03-30  19546.509

# %% [markdown]
# Additional features are listing the unique countries for which the loss for each volcano eruption has been calculated

# %%
content['country'].unique()
# Out:
# array(['St. Vincent & the Grenadines', 'Martinique', 'Guatemala', 'Japan',
#        'Papua New Guinea', 'United States', 'Iceland', 'Indonesia',
#        'Mexico', 'Colombia', 'Philippines', 'Italy', 'Nicaragua',
#        'Congo, DRC', 'Spain', 'Tonga'], dtype=object)

# %% [markdown]
# The result of the cumulative sum can be also obtained by adding at once the values of the loss column in a single step

# %%
total_loss = content['loss'].sum()
'Total Loss is '+str(total_loss)+' Million US$'
# Out:
# 'Total Loss is 19546.509 Million US$'

# %% [markdown]
# This sum can be also performed for a particular value in a particular column. Let's consider for instance the icelandic volcanoes. Using the .loc function we spot those volcanos located in Iceland and then we perform the sum.

# %%
total_loss_Iceland=content['loss'].loc[content['country']=='Iceland'].sum()
'Total Loss in Iceland is '+str(total_loss_Iceland)+' Million US$'
# Out:
# 'Total Loss in Iceland is 5200.0 Million US$'

# %% [markdown]
# Another built-in mathematical operations such as max, min, mean and standard deviation are available in Pandas. For the mean and std in Iceland we obtain:

# %%
mean_loss_Iceland=content['loss'].loc[content['country']=='Iceland'].mean()
std_loss_Iceland=content['loss'].loc[content['country']=='Iceland'].std()
'Mean Loss in Iceland is '+str(mean_loss_Iceland)+' Million US$ with '+str(std_loss_Iceland)+' standard deviation'
# Out:
# 'Mean Loss in Iceland is 2600.0 Million US$ with 3394.1125496954282 standard deviation'

# %% [markdown]
# Max of a whole column can also be calculated with the traditional Numpy functions

# %%
np.max(content['loss'])
# Out:
# 5000.0

# %% [markdown]
# Min of a column

# %%
np.min(content['loss'])
# Out:
# 1.0

# %% [markdown]
# Pandas dataframe allow also filtering by thresholds

# %%
content = content[content['loss'] > 1000] 
content
# Out:
#                 name        country    loss       date   loss_acc
# 11        St. Helens  United States  2000.0 1980-05-18   4556.590
# 28  Eyjafjallajokull        Iceland  5000.0 2010-03-31  12301.060
# 31          Sinabung      Indonesia  3295.0 2010-08-30  15669.445

# %% [markdown]
# Operations on all values of a column can also be performed creating a new column with the output

# %%
content['ratio'] = content['loss']/content['loss'].sum()
content
# Out:
#                 name        country    loss       date   loss_acc     ratio
# 11        St. Helens  United States  2000.0 1980-05-18   4556.590  0.194269
# 28  Eyjafjallajokull        Iceland  5000.0 2010-03-31  12301.060  0.485673
# 31          Sinabung      Indonesia  3295.0 2010-08-30  15669.445  0.320058

# %% [markdown]
# In case we need the values of a particular column as an array, we use the .tolist() function

# %%
content['ratio'].values.tolist()
# Out:
# [0.1942690626517727, 0.48567265662943176, 0.32005828071879555]

# %% [markdown]
# Alternativelo, operations inside columns can be done via mapping the column

# %%
content['loss_billions']= content['loss'].apply(lambda x: x/1000)
content
# Out:
#                 name        country    loss       date   loss_acc     ratio  \
# 11        St. Helens  United States  2000.0 1980-05-18   4556.590  0.194269
# 28  Eyjafjallajokull        Iceland  5000.0 2010-03-31  12301.060  0.485673
# 31          Sinabung      Indonesia  3295.0 2010-08-30  15669.445  0.320058
#
#     loss_billions
# 11          2.000
# 28          5.000
# 31          3.295

# %% [markdown]
# Using the datetime package, we can include an extra column with the current date and time.

# %%
today = datetime.datetime.now()
content['now'] = today
content
# Out:
#                 name        country    loss       date   loss_acc     ratio  \
# 11        St. Helens  United States  2000.0 1980-05-18   4556.590  0.194269
# 28  Eyjafjallajokull        Iceland  5000.0 2010-03-31  12301.060  0.485673
# 31          Sinabung      Indonesia  3295.0 2010-08-30  15669.445  0.320058
#
#     loss_billions                        now
# 11          2.000 2024-11-26 10:25:20.567821
# 28          5.000 2024-11-26 10:25:20.567821
# 31          3.295 2024-11-26 10:25:20.567821

# %% [markdown]
# We can estimate the difference between today and the eruption dates in hours

# %%
content['hours_gone']=(content.now-content.date).astype('timedelta64[h]')
content
# Out:
#                 name        country    loss       date   loss_acc     ratio  \
# 11        St. Helens  United States  2000.0 1980-05-18   4556.590  0.194269
# 28  Eyjafjallajokull        Iceland  5000.0 2010-03-31  12301.060  0.485673
# 31          Sinabung      Indonesia  3295.0 2010-08-30  15669.445  0.320058
#
#     loss_billions                        now  hours_gone
# 11          2.000 2024-11-26 10:25:20.567821    390322.0
# 28          5.000 2024-11-26 10:25:20.567821    128506.0
# 31          3.295 2024-11-26 10:25:20.567821    124858.0

# %% [markdown]
# And perform simple operations to change hours into whatever other time metric we choose

# %%
content['days_gone']= content['hours_gone'].apply(lambda x: x/24)
content
# Out:
#                 name        country    loss       date   loss_acc     ratio  \
# 11        St. Helens  United States  2000.0 1980-05-18   4556.590  0.194269
# 28  Eyjafjallajokull        Iceland  5000.0 2010-03-31  12301.060  0.485673
# 31          Sinabung      Indonesia  3295.0 2010-08-30  15669.445  0.320058
#
#     loss_billions                        now  hours_gone     days_gone
# 11          2.000 2024-11-26 10:25:20.567821    390322.0  16263.416667
# 28          5.000 2024-11-26 10:25:20.567821    128506.0   5354.416667
# 31          3.295 2024-11-26 10:25:20.567821    124858.0   5202.416667
