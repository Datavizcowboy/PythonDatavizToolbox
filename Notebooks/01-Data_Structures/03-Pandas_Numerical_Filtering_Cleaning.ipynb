# %% [markdown]
# # Pandas Cleaning and Filtering

# %% [markdown]
# Libraries we need are imported first

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Data used in this exercise is from worldwide airport locations and details

# %%
data_path = '../../DATA/airports.csv'

# %% [markdown]
# The dataframe is created using the .read_csv function

# %%
content = pd.read_csv(data_path)
content
# Out:
#       icao iata                        name        lat         lon    elev  \
# 0     AYGA  GKA                      Goroka  -6.081689  145.391881  1566.0
# 1     AYMD  MAG                      Madang  -5.207083  145.788700     8.0
# 2     AYMH  HGU                 Mount Hagen  -5.826789  144.295861  1636.0
# 3     AYNZ  LAE                      Nadzab  -6.569828  146.726242    65.0
# 4     AYPY  POM  Port Moresby Jacksons Intl  -9.443383  147.220050    50.0
# ...    ...  ...                         ...        ...         ...     ...
# 8887  LFPQ  NaN           Fontenay Tresigny  48.707222    2.904444    98.0
# 8888  KASY  ASY                 ASHLEY MUNI  46.024951  -99.351260   615.0
# 8889  LFDR  NaN            La Reole Floudes  44.568054   -0.056111    20.0
# 8890  SDDR  NaN                     Dracena -21.460511  -51.606898   365.0
# 8891  SLAS  ASC       Ascension De Guarayos -15.719167  -63.091946   217.0
#
#                         tz                        name_ext  \
# 0     Pacific/Port_Moresby                  Goroka Airport
# 1     Pacific/Port_Moresby                  Madang Airport
# 2     Pacific/Port_Moresby             Mount Hagen Airport
# 3     Pacific/Port_Moresby              Lae Nadzab Airport
# 4     Pacific/Port_Moresby  Jacksons International Airport
# ...                    ...                             ...
# 8887          Europe/Paris                             NaN
# 8888       America/Chicago        Ashley Municipal Airport
# 8889          Europe/Paris                             NaN
# 8890     America/Sao_Paulo                             NaN
# 8891        America/La_Paz   Ascención de Guarayos Airport
#
#                        city         region            country
# 0                    Goroka            NaN   Papua New Guinea
# 1                    Madang            NaN   Papua New Guinea
# 2               Mount Hagen            NaN   Papua New Guinea
# 3                       Lae            NaN   Papua New Guinea
# 4              Port Moresby            NaN   Papua New Guinea
# ...                     ...            ...                ...
# 8887                    NaN            NaN                NaN
# 8888                 Ashley   North Dakota      United States
# 8889                    NaN            NaN                NaN
# 8890                    NaN            NaN                NaN
# 8891  Ascención de Guarayos            NaN            Bolivia
#
# [8892 rows x 11 columns]

# %% [markdown]
# The original CSV file is structured as a dataframe with the corresponding categories

# %%
content = content[content.elev == 217.0]
content
# Out:
#       icao iata                                             name        lat  \
# 1993  UATT  AKX                                       Aktyubinsk  50.245833
# 4912  CYGM  YGM                    Gimli Industrial Park Airport  50.628056
# 5225  EDTF  NaN                          Freiburg i. Br. Airport  48.022778
# 5338  LGTT  NaN                                    Tatoi Airport  38.108898
# 5958  EPZA  NaN                           ZamoÅ›Ä‡-Mokre Airport  50.701698
# 6228  KCFS  TZC                             Tuscola Area Airport  43.458801
# 6381  KFSW  FMS                   Fort Madison Municipal Airport  40.659302
# 6771  KSWI  NaN                        Sherman Municipal Airport  33.624199
# 6832  KVPZ  VPZ                  Porter County Municipal Airport  41.453999
# 7744  SPAS  AOP  Alferez FAP Alfredo Vladimir Sara Bauer Airport  -2.796130
# 8108  YMEL  NaN                                   Melton Airport -37.616699
# 8891  SLAS  ASC                            Ascension De Guarayos -15.719167
#
#              lon   elev                   tz  \
# 1993   57.206667  217.0          Asia/Aqtobe
# 4912  -97.043333  217.0     America/Winnipeg
# 5225    7.832500  217.0        Europe/Berlin
# 5338   23.783800  217.0        Europe/Athens
# 5958   23.204399  217.0        Europe/Warsaw
# 6228  -83.445503  217.0      America/Detroit
# 6381  -91.326797  217.0      America/Chicago
# 6771  -96.586098  217.0      America/Chicago
# 6832  -87.007103  217.0      America/Chicago
# 7744  -76.466599  217.0         America/Lima
# 8108  144.567001  217.0  Australia/Melbourne
# 8891  -63.091946  217.0       America/La_Paz
#
#                                        name_ext                   city  \
# 1993                             Aktobe Airport                 Aktobe
# 4912              Gimli Industrial Park Airport                  Gimli
# 5225                                        NaN                    NaN
# 5338                                        NaN                    NaN
# 5958                                        NaN                    NaN
# 6228         Tuscola Area Airport[1] (FAA: CFS)                   Caro
# 6381  Fort Madison Municipal Airport (FAA: FSW)           Fort Madison
# 6771                                        NaN                    NaN
# 6832             Porter County Regional Airport             Valparaiso
# 7744                                        NaN                    NaN
# 8108                                        NaN                    NaN
# 8891              Ascención de Guarayos Airport  Ascención de Guarayos
#
#          region         country
# 1993        NaN      Kazakhstan
# 4912   Manitoba          Canada
# 5225        NaN             NaN
# 5338        NaN             NaN
# 5958        NaN             NaN
# 6228   Michigan   United States
# 6381       Iowa   United States
# 6771        NaN             NaN
# 6832    Indiana   United States
# 7744        NaN             NaN
# 8108        NaN             NaN
# 8891        NaN         Bolivia

# %%
content= content.dropna()
content
# Out:
#       icao iata                             name        lat        lon   elev  \
# 4912  CYGM  YGM    Gimli Industrial Park Airport  50.628056 -97.043333  217.0
# 6228  KCFS  TZC             Tuscola Area Airport  43.458801 -83.445503  217.0
# 6381  KFSW  FMS   Fort Madison Municipal Airport  40.659302 -91.326797  217.0
# 6832  KVPZ  VPZ  Porter County Municipal Airport  41.453999 -87.007103  217.0
#
#                     tz                                   name_ext  \
# 4912  America/Winnipeg              Gimli Industrial Park Airport
# 6228   America/Detroit         Tuscola Area Airport[1] (FAA: CFS)
# 6381   America/Chicago  Fort Madison Municipal Airport (FAA: FSW)
# 6832   America/Chicago             Porter County Regional Airport
#
#               city     region         country
# 4912         Gimli   Manitoba          Canada
# 6228          Caro   Michigan   United States
# 6381  Fort Madison       Iowa   United States
# 6832    Valparaiso    Indiana   United States

# %% [markdown]
# Dropping by category

# %% [markdown]
# To Numeric format

# %%
content["elev"] = pd.to_numeric(content["elev"])
content
# Out:
# /var/folders/5k/mjzbrl8j1773drpygwd3n0mm0000gn/T/ipykernel_50035/878115623.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   content["elev"] = pd.to_numeric(content["elev"])
#       icao iata                             name        lat        lon   elev  \
# 4912  CYGM  YGM    Gimli Industrial Park Airport  50.628056 -97.043333  217.0
# 6228  KCFS  TZC             Tuscola Area Airport  43.458801 -83.445503  217.0
# 6381  KFSW  FMS   Fort Madison Municipal Airport  40.659302 -91.326797  217.0
# 6832  KVPZ  VPZ  Porter County Municipal Airport  41.453999 -87.007103  217.0
#
#                     tz                                   name_ext  \
# 4912  America/Winnipeg              Gimli Industrial Park Airport
# 6228   America/Detroit         Tuscola Area Airport[1] (FAA: CFS)
# 6381   America/Chicago  Fort Madison Municipal Airport (FAA: FSW)
# 6832   America/Chicago             Porter County Regional Airport
#
#               city     region         country
# 4912         Gimli   Manitoba          Canada
# 6228          Caro   Michigan   United States
# 6381  Fort Madison       Iowa   United States
# 6832    Valparaiso    Indiana   United States

# %% [markdown]
# Display column value

# %%
capturas = mycapt[["capt"]].values

# %% [markdown]
# Sum of column

# %%
total_revenue=mypanda['rev'].sum()
total_revenue_q1=mypanda['rev'].loc[mypanda['qua']==1].sum()

# %% [markdown]
# Mean of a column

# %%
smallbuyersave = mypanda['rev'].loc[mypanda['ord']<10].mean()

# %% [markdown]
# Histogram based on pandas

# %%
pd.Series(data).value_counts().plot(kind='bar')
