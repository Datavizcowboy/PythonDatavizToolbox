# %% [markdown]
# We first import the required modules

# %%
import numpy as np
import pandas as pd
import json

# %% [markdown]
# We first read the blablabla

# %%
data_path = '../../DATA/volcanic-eruption-database.json'

# %%
with open(data_path) as f:
    data = json.load(f)

# %%
data
# Out:
# [{'year': 2010,
#   'month': '07',
#   'day': '03',
#   'tsu': None,
#   'eq': None,
#   'name': 'Stromboli',
#   'location': 'Italy',
#   'country': 'Italy',
#   'elevation': 926,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': 1,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': 1.0,
#   'injuries_description': 'Few (~1 to 50 deaths)',
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 1,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': 1.0,
#   'total_injuries_description': 'Few (~1 to 50 deaths)',
#   'total_damage_millions_dollars': 5,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 15.213, 'lat': 38.789},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 2010,
#   'month': '03',
#   'day': '25',
#   'tsu': None,
#   'eq': None,
#   'name': 'Bromo',
#   'location': 'Java',
#   'country': 'Indonesia',
#   'elevation': 2947,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 3,
#   'deaths': 32,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': 'Some (~51 to 100 houses)',
#   'total_deaths': 32,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': 5.55,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': 'Some (~51 to 100 houses)',
#   'coordinates': {'lon': 110.442, 'lat': -7.542},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 2010,
#   'month': '03',
#   'day': '25',
#   'tsu': None,
#   'eq': None,
#   'name': 'Tunguruhua',
#   'location': 'Java',
#   'country': 'Indonesia',
#   'elevation': 2947,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 3,
#   'deaths': 32,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': 'Some (~51 to 100 houses)',
#   'total_deaths': 32,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': 160.22,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': 'Some (~51 to 100 houses)',
#   'coordinates': {'lon': 110.442, 'lat': -7.542},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1982,
#   'month': '03',
#   'day': '25',
#   'tsu': None,
#   'eq': None,
#   'name': 'Galanggung',
#   'location': 'Java',
#   'country': 'Indonesia',
#   'elevation': 2947,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 3,
#   'deaths': 32,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': 'Some (~51 to 100 houses)',
#   'total_deaths': 32,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': 100,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': 'Some (~51 to 100 houses)',
#   'coordinates': {'lon': 110.442, 'lat': -7.542},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1990,
#   'month': '03',
#   'day': '19',
#   'tsu': None,
#   'eq': None,
#   'name': 'Kilauea',
#   'location': 'Hawaiian Is',
#   'country': 'United States',
#   'elevation': 1222,
#   'type': 'Shield volcano',
#   'status': 'Historical',
#   'vei': None,
#   'deaths': 1,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': 22.0,
#   'injuries_description': 'Few (~1 to 50 deaths)',
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 1,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': 22.0,
#   'total_injuries_description': 'Few (~1 to 50 deaths)',
#   'total_damage_millions_dollars': 100.5,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -155.292, 'lat': 19.425},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1960,
#   'month': '03',
#   'day': '19',
#   'tsu': None,
#   'eq': None,
#   'name': 'Kilauea',
#   'location': 'Hawaiian Is',
#   'country': 'United States',
#   'elevation': 1222,
#   'type': 'Shield volcano',
#   'status': 'Historical',
#   'vei': None,
#   'deaths': 1,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': 22.0,
#   'injuries_description': 'Few (~1 to 50 deaths)',
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 1,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': 22.0,
#   'total_injuries_description': 'Few (~1 to 50 deaths)',
#   'total_damage_millions_dollars': 6,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -155.292, 'lat': 19.425},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 2021,
#   'month': '03',
#   'day': '13',
#   'tsu': None,
#   'eq': None,
#   'name': 'Soufriere St. Vincent',
#   'location': 'W Indies',
#   'country': 'St. Vincent & the Grenadines',
#   'elevation': 1220,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 3,
#   'deaths': 2,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 2,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': 400,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -61.18, 'lat': 13.33},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1976,
#   'month': '03',
#   'day': '13',
#   'tsu': None,
#   'eq': None,
#   'name': 'Soufriere St. Vincent',
#   'location': 'W Indies',
#   'country': 'St. Vincent & the Grenadines',
#   'elevation': 1220,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 3,
#   'deaths': 2,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 2,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': 1000,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -61.18, 'lat': 13.33},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 2021,
#   'month': '05',
#   'day': '05',
#   'tsu': 'Tsunami',
#   'eq': None,
#   'name': 'Cumbre Vieja',
#   'location': 'Canary Is',
#   'country': 'Spain',
#   'elevation': 3715,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': None,
#   'deaths_description': None,
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': 'SEVERE (~>$5 to $24 million)',
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': None,
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': 906,
#   'total_damage_description': 'SEVERE (~>$5 to $24 million)',
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -16.641, 'lat': 28.271},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1955,
#   'month': '04',
#   'day': '19',
#   'tsu': None,
#   'eq': None,
#   'name': 'Kilauea',
#   'location': 'Hawaiian Is',
#   'country': 'United States',
#   'elevation': 1222,
#   'type': 'Shield volcano',
#   'status': 'Historical',
#   'vei': None,
#   'deaths': 1,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': 22.0,
#   'injuries_description': 'Few (~1 to 50 deaths)',
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 1,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': 22.0,
#   'total_injuries_description': 'Few (~1 to 50 deaths)',
#   'total_damage_millions_dollars': 2.59,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -155.292, 'lat': 19.425},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 2022,
#   'month': '03',
#   'day': '30',
#   'tsu': 'Tsunami',
#   'eq': None,
#   'name': "Hunga Tonga-Hunga Ha'apai",
#   'location': 'Tonga-SW Pacific',
#   'country': 'Tonga',
#   'elevation': 512,
#   'type': 'Caldera',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': None,
#   'deaths_description': None,
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': None,
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': 90,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -175.07, 'lat': -19.75},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1995,
#   'month': '04',
#   'day': '27',
#   'tsu': None,
#   'eq': None,
#   'name': 'Soufriere St. Vincent',
#   'location': 'W Indies',
#   'country': 'St. Vincent & the Grenadines',
#   'elevation': 1220,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 4,
#   'deaths': 56,
#   'deaths_description': 'Some (~51 to 100 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 56,
#   'total_deaths_description': 'Some (~51 to 100 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': 500,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -61.18, 'lat': 13.33},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1994,
#   'month': '02',
#   'day': None,
#   'tsu': None,
#   'eq': None,
#   'name': 'Tavurvur',
#   'location': 'Iceland',
#   'country': 'iceland',
#   'elevation': 3914,
#   'type': 'Caldera',
#   'status': 'Radiocarbon',
#   'vei': 6,
#   'deaths': None,
#   'deaths_description': None,
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': 'LIMITED (roughly corresponding to less than $1 million)',
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': None,
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': 300,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -78.9, 'lat': -0.85},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1280,
#   'month': None,
#   'day': None,
#   'tsu': None,
#   'eq': None,
#   'name': 'Quilotoa',
#   'location': 'Ecuador',
#   'country': 'Ecuador',
#   'elevation': 3914,
#   'type': 'Caldera',
#   'status': 'Radiocarbon',
#   'vei': 6,
#   'deaths': None,
#   'deaths_description': None,
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': 'LIMITED (roughly corresponding to less than $1 million)',
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': None,
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -78.9, 'lat': -0.85},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1540,
#   'month': None,
#   'day': None,
#   'tsu': 'Tsunami',
#   'eq': None,
#   'name': 'Augustine',
#   'location': 'Alaska-SW',
#   'country': 'United States',
#   'elevation': 1252,
#   'type': 'Lava dome',
#   'status': 'Historical',
#   'vei': 4,
#   'deaths': None,
#   'deaths_description': None,
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': None,
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -153.42, 'lat': 59.37},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1660,
#   'month': None,
#   'day': None,
#   'tsu': 'Tsunami',
#   'eq': None,
#   'name': 'Long Island',
#   'location': 'New Guinea-NE of',
#   'country': 'Papua New Guinea',
#   'elevation': 1280,
#   'type': 'Complex volcano',
#   'status': 'Historical',
#   'vei': 6,
#   'deaths': 2000,
#   'deaths_description': 'Very Many (~1001 or more deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': 'SEVERE (~>$5 to $24 million)',
#   'houses_destroyed': None,
#   'houses_destroyed_description': 'Many (~101 to 1000 houses)',
#   'total_deaths': 2000,
#   'total_deaths_description': 'Very Many (~1001 or more deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': 'SEVERE (~>$5 to $24 million)',
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': 'Many (~101 to 1000 houses)',
#   'coordinates': {'lon': 147.12, 'lat': -5.358},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1858,
#   'month': '04',
#   'day': '23',
#   'tsu': None,
#   'eq': 'Earthquake',
#   'name': 'Tate-yama',
#   'location': 'Honshu-Japan',
#   'country': 'Japan',
#   'elevation': 2621,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': None,
#   'deaths': None,
#   'deaths_description': 'Many (~101 to 1000 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': 'Many (~101 to 1000 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 137.6, 'lat': 36.57},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1864,
#   'month': '01',
#   'day': '03',
#   'tsu': None,
#   'eq': None,
#   'name': 'Kelut',
#   'location': 'Java',
#   'country': 'Indonesia',
#   'elevation': 1731,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': 54,
#   'deaths_description': 'Some (~51 to 100 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': 'Many (~101 to 1000 houses)',
#   'total_deaths': 54,
#   'total_deaths_description': 'Some (~51 to 100 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': 'Many (~101 to 1000 houses)',
#   'coordinates': {'lon': 112.308, 'lat': -7.93},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1873,
#   'month': '01',
#   'day': '16',
#   'tsu': None,
#   'eq': None,
#   'name': 'Ragang',
#   'location': 'Mindanao-Philippines',
#   'country': 'Philippines',
#   'elevation': 2815,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': None,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 124.5, 'lat': 7.67},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1902,
#   'month': '08',
#   'day': '07',
#   'tsu': None,
#   'eq': None,
#   'name': 'Tori-shima',
#   'location': 'Izu Is-Japan',
#   'country': 'Japan',
#   'elevation': 403,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 3,
#   'deaths': 125,
#   'deaths_description': 'Many (~101 to 1000 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 125,
#   'total_deaths_description': 'Many (~101 to 1000 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 140.32, 'lat': 30.48},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1907,
#   'month': '08',
#   'day': '04',
#   'tsu': None,
#   'eq': None,
#   'name': 'Alayta',
#   'location': 'Africa-NE',
#   'country': 'Ethiopia',
#   'elevation': 1501,
#   'type': 'Shield volcano',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': None,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 40.57, 'lat': 12.88},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1909,
#   'month': '09',
#   'day': None,
#   'tsu': None,
#   'eq': None,
#   'name': 'Semeru',
#   'location': 'Java',
#   'country': 'Indonesia',
#   'elevation': 3676,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': 221,
#   'deaths_description': 'Many (~101 to 1000 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': 'LIMITED (roughly corresponding to less than $1 million)',
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 221,
#   'total_deaths_description': 'Many (~101 to 1000 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': 'LIMITED (roughly corresponding to less than $1 million)',
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 112.92, 'lat': -8.108},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1919,
#   'month': '05',
#   'day': '19',
#   'tsu': None,
#   'eq': None,
#   'name': 'Kelut',
#   'location': 'Java',
#   'country': 'Indonesia',
#   'elevation': 1731,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 4,
#   'deaths': 5110,
#   'deaths_description': 'Very Many (~1001 or more deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': '9000',
#   'houses_destroyed_description': 'Very Many (~1001 or more houses)',
#   'total_deaths': 5110,
#   'total_deaths_description': 'Very Many (~1001 or more deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': '9000',
#   'total_houses_destroyed_description': 'Very Many (~1001 or more houses)',
#   'coordinates': {'lon': 112.308, 'lat': -7.93},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1919,
#   'month': '07',
#   'day': '06',
#   'tsu': None,
#   'eq': None,
#   'name': 'Nasu',
#   'location': 'Honshu-Japan',
#   'country': 'Japan',
#   'elevation': 1917,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': None,
#   'deaths': 2,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 2,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 139.97, 'lat': 37.12},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1920,
#   'month': '10',
#   'day': '29',
#   'tsu': None,
#   'eq': None,
#   'name': 'Izalco',
#   'location': 'El Salvador',
#   'country': 'El Salvador',
#   'elevation': 1950,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 3,
#   'deaths': None,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -89.633, 'lat': 13.813},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1938,
#   'month': '05',
#   'day': '09',
#   'tsu': None,
#   'eq': None,
#   'name': 'Bandai',
#   'location': 'Honshu-Japan',
#   'country': 'Japan',
#   'elevation': 1819,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': None,
#   'deaths': 2,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 2,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 140.08, 'lat': 37.6},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1949,
#   'month': '01',
#   'day': '01',
#   'tsu': None,
#   'eq': None,
#   'name': 'Villarrica',
#   'location': 'Chile-C',
#   'country': 'Chile',
#   'elevation': 2847,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 3,
#   'deaths': 54,
#   'deaths_description': 'Some (~51 to 100 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': 'MODERATE (~$1 to $5 million)',
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 54,
#   'total_deaths_description': 'Some (~51 to 100 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': 'MODERATE (~$1 to $5 million)',
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -71.93, 'lat': -39.42},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1963,
#   'month': '09',
#   'day': '28',
#   'tsu': None,
#   'eq': None,
#   'name': 'Fuego',
#   'location': 'Guatemala',
#   'country': 'Guatemala',
#   'elevation': 3763,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 3,
#   'deaths': 7,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 7,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -90.88, 'lat': 14.473},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1968,
#   'month': '04',
#   'day': '21',
#   'tsu': None,
#   'eq': None,
#   'name': 'Mayon',
#   'location': 'Luzon-Philippines',
#   'country': 'Philippines',
#   'elevation': 2462,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 3,
#   'deaths': 6,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 6,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 123.685, 'lat': 13.257},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1985,
#   'month': '05',
#   'day': '10',
#   'tsu': None,
#   'eq': None,
#   'name': 'Semeru',
#   'location': 'Java',
#   'country': 'Indonesia',
#   'elevation': 3676,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 3,
#   'deaths': 70,
#   'deaths_description': 'Some (~51 to 100 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 70,
#   'total_deaths_description': 'Some (~51 to 100 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 112.92, 'lat': -8.108},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1992,
#   'month': '07',
#   'day': '05',
#   'tsu': None,
#   'eq': None,
#   'name': 'Marapi',
#   'location': 'Sumatra',
#   'country': 'Indonesia',
#   'elevation': 2891,
#   'type': 'Complex volcano',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': 1,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': 5.0,
#   'injuries_description': 'Few (~1 to 50 deaths)',
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 1,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': 5.0,
#   'total_injuries_description': 'Few (~1 to 50 deaths)',
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 100.473, 'lat': -0.381},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 2001,
#   'month': '10',
#   'day': '20',
#   'tsu': None,
#   'eq': None,
#   'name': 'Stromboli',
#   'location': 'Italy',
#   'country': 'Italy',
#   'elevation': 926,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': 1,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 1,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 15.213, 'lat': 38.789},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 2004,
#   'month': '10',
#   'day': '24',
#   'tsu': None,
#   'eq': None,
#   'name': 'Manam',
#   'location': 'New Guinea-NE of',
#   'country': 'Papua New Guinea',
#   'elevation': 1807,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 4,
#   'deaths': 5,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 5,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 145.061, 'lat': -4.1},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 2010,
#   'month': '05',
#   'day': '29',
#   'tsu': 'Tsunami',
#   'eq': 'Earthquake',
#   'name': 'Sarigan',
#   'location': 'Mariana Is-C Pacific',
#   'country': 'United States',
#   'elevation': 538,
#   'type': 'Stratovolcano',
#   'status': 'Holocene',
#   'vei': None,
#   'deaths': None,
#   'deaths_description': None,
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': None,
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 145.78, 'lat': 16.708},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 2018,
#   'month': '12',
#   'day': '26',
#   'tsu': None,
#   'eq': 'Earthquake',
#   'name': 'Etna',
#   'location': 'Italy',
#   'country': 'Italy',
#   'elevation': 3350,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': None,
#   'deaths_description': None,
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': None,
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': 28.0,
#   'total_injuries_description': 'Few (~1 to 50 deaths)',
#   'total_damage_millions_dollars': '115',
#   'total_damage_description': 'EXTREME (~$25 million or more)',
#   'total_houses_destroyed': '15',
#   'total_houses_destroyed_description': 'Few (~1 to 50 houses)',
#   'coordinates': {'lon': 15.004, 'lat': 37.734},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 2020,
#   'month': '01',
#   'day': '12',
#   'tsu': None,
#   'eq': None,
#   'name': 'Taal',
#   'location': 'Luzon-Philippines',
#   'country': 'Philippines',
#   'elevation': 400,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': None,
#   'deaths': None,
#   'deaths_description': None,
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': 67.0,
#   'damage_description': 'EXTREME (~$25 million or more)',
#   'houses_destroyed': '4573',
#   'houses_destroyed_description': 'Very Many (~1001 or more houses)',
#   'total_deaths': None,
#   'total_deaths_description': None,
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': '67',
#   'total_damage_description': 'EXTREME (~$25 million or more)',
#   'total_houses_destroyed': '4573',
#   'total_houses_destroyed_description': 'Very Many (~1001 or more houses)',
#   'coordinates': {'lon': 120.993, 'lat': 14.002},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1357,
#   'month': None,
#   'day': None,
#   'tsu': None,
#   'eq': None,
#   'name': 'Katla',
#   'location': 'Iceland-S',
#   'country': 'Iceland',
#   'elevation': 1512,
#   'type': 'Subglacial volcano',
#   'status': 'Historical',
#   'vei': 4,
#   'deaths': None,
#   'deaths_description': None,
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': 'LIMITED (roughly corresponding to less than $1 million)',
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': None,
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': 'LIMITED (roughly corresponding to less than $1 million)',
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -19.05, 'lat': 63.63},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1586,
#   'month': None,
#   'day': None,
#   'tsu': None,
#   'eq': None,
#   'name': 'Kelut',
#   'location': 'Java',
#   'country': 'Indonesia',
#   'elevation': 1731,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 5,
#   'deaths': 10000,
#   'deaths_description': 'Very Many (~1001 or more deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 10000,
#   'total_deaths_description': 'Very Many (~1001 or more deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 112.308, 'lat': -7.93},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1730,
#   'month': None,
#   'day': None,
#   'tsu': None,
#   'eq': None,
#   'name': 'Tseax River Cone',
#   'location': 'Canada',
#   'country': 'Canada',
#   'elevation': 609,
#   'type': 'Pyroclastic cone',
#   'status': 'Radiocarbon',
#   'vei': None,
#   'deaths': None,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -128.9, 'lat': 55.12},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1823,
#   'month': '02',
#   'day': None,
#   'tsu': None,
#   'eq': None,
#   'name': 'Kilauea',
#   'location': 'Hawaiian Is',
#   'country': 'United States',
#   'elevation': 1222,
#   'type': 'Shield volcano',
#   'status': 'Historical',
#   'vei': 0,
#   'deaths': None,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -155.292, 'lat': 19.425},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1832,
#   'month': '12',
#   'day': '25',
#   'tsu': None,
#   'eq': None,
#   'name': 'Merapi',
#   'location': 'Java',
#   'country': 'Indonesia',
#   'elevation': 2947,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 3,
#   'deaths': 32,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': 'Some (~51 to 100 houses)',
#   'total_deaths': 32,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': 'Some (~51 to 100 houses)',
#   'coordinates': {'lon': 110.442, 'lat': -7.542},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1838,
#   'month': '02',
#   'day': '26',
#   'tsu': None,
#   'eq': None,
#   'name': 'Gamalama',
#   'location': 'Halmahera-Indonesia',
#   'country': 'Indonesia',
#   'elevation': 1715,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': 4,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 4,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 127.325, 'lat': 0.8},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1858,
#   'month': '01',
#   'day': None,
#   'tsu': None,
#   'eq': None,
#   'name': 'Mayon',
#   'location': 'Luzon-Philippines',
#   'country': 'Philippines',
#   'elevation': 2462,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': None,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 123.685, 'lat': 13.257},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1872,
#   'month': '12',
#   'day': None,
#   'tsu': None,
#   'eq': None,
#   'name': 'Aso',
#   'location': 'Kyushu-Japan',
#   'country': 'Japan',
#   'elevation': 1592,
#   'type': 'Caldera',
#   'status': 'Historical',
#   'vei': 3,
#   'deaths': 4,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 4,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 131.1, 'lat': 32.88},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1879,
#   'month': '02',
#   'day': '04',
#   'tsu': 'Tsunami',
#   'eq': None,
#   'name': 'Stromboli',
#   'location': 'Italy',
#   'country': 'Italy',
#   'elevation': 926,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': None,
#   'deaths_description': None,
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': None,
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 15.213, 'lat': 38.789},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1893,
#   'month': '05',
#   'day': '19',
#   'tsu': None,
#   'eq': None,
#   'name': 'Azuma',
#   'location': 'Honshu-Japan',
#   'country': 'Japan',
#   'elevation': 2024,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': 2,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
# ...
#   'country': 'Indonesia',
#   'elevation': 2565,
#   'type': 'Complex volcano',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': 117,
#   'deaths_description': 'Many (~101 to 1000 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': 250.0,
#   'injuries_description': 'Many (~101 to 1000 deaths)',
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 117,
#   'total_deaths_description': 'Many (~101 to 1000 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': 250.0,
#   'total_injuries_description': 'Many (~101 to 1000 deaths)',
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 109.92, 'lat': -7.2},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1953,
#   'month': '10',
#   'day': '05',
#   'tsu': None,
#   'eq': None,
#   'name': 'Oshima',
#   'location': 'Izu Is-Japan',
#   'country': 'Japan',
#   'elevation': 758,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 1,
#   'deaths': 1,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 1,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 139.38, 'lat': 34.73},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1973,
#   'month': '04',
#   'day': '05',
#   'tsu': None,
#   'eq': None,
#   'name': 'Hudson, Cerro',
#   'location': 'Chile-S',
#   'country': 'Chile',
#   'elevation': 1905,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': None,
#   'deaths': 2,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': 'LIMITED (roughly corresponding to less than $1 million)',
#   'houses_destroyed': None,
#   'houses_destroyed_description': 'Few (~1 to 50 houses)',
#   'total_deaths': 2,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': 'LIMITED (roughly corresponding to less than $1 million)',
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': 'Few (~1 to 50 houses)',
#   'coordinates': {'lon': -72.97, 'lat': -45.9},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1990,
#   'month': '04',
#   'day': '18',
#   'tsu': None,
#   'eq': None,
#   'name': 'Aso',
#   'location': 'Kyushu-Japan',
#   'country': 'Japan',
#   'elevation': 1592,
#   'type': 'Caldera',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': 1,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 1,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 131.1, 'lat': 32.88},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1991,
#   'month': '06',
#   'day': '15',
#   'tsu': None,
#   'eq': 'Earthquake',
#   'name': 'Pinatubo',
#   'location': 'Luzon-Philippines',
#   'country': 'Philippines',
#   'elevation': 1486,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 6,
#   'deaths': 350,
#   'deaths_description': 'Many (~101 to 1000 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': 4.0,
#   'injuries_description': 'Few (~1 to 50 deaths)',
#   'damage_millions_dollars': None,
#   'damage_description': 'SEVERE (~>$5 to $24 million)',
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 800,
#   'total_deaths_description': 'Many (~101 to 1000 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': 4.0,
#   'total_injuries_description': 'Few (~1 to 50 deaths)',
#   'total_damage_millions_dollars': 750,
#   'total_damage_description': 'SEVERE (~>$5 to $24 million)',
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 120.35, 'lat': 15.13},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1992,
#   'month': '07',
#   'day': '12',
#   'tsu': None,
#   'eq': None,
#   'name': 'Pinatubo',
#   'location': 'Luzon-Philippines',
#   'country': 'Philippines',
#   'elevation': 1486,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 1,
#   'deaths': 6,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 6,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 120.35, 'lat': 15.13},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1995,
#   'month': '04',
#   'day': '02',
#   'tsu': None,
#   'eq': None,
#   'name': 'Fogo',
#   'location': 'Cape Verde Is',
#   'country': 'Cape Verde',
#   'elevation': 2829,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': None,
#   'deaths_description': None,
#   'missing': None,
#   'missing_description': None,
#   'injuries': 20.0,
#   'injuries_description': 'Few (~1 to 50 deaths)',
#   'damage_millions_dollars': None,
#   'damage_description': 'LIMITED (roughly corresponding to less than $1 million)',
#   'houses_destroyed': '10',
#   'houses_destroyed_description': 'Few (~1 to 50 houses)',
#   'total_deaths': None,
#   'total_deaths_description': None,
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': 20.0,
#   'total_injuries_description': 'Few (~1 to 50 deaths)',
#   'total_damage_millions_dollars': None,
#   'total_damage_description': 'LIMITED (roughly corresponding to less than $1 million)',
#   'total_houses_destroyed': '10',
#   'total_houses_destroyed_description': 'Few (~1 to 50 houses)',
#   'coordinates': {'lon': -24.35, 'lat': 14.95},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 1996,
#   'month': '12',
#   'day': '03',
#   'tsu': None,
#   'eq': None,
#   'name': 'Manam',
#   'location': 'New Guinea-NE of',
#   'country': 'Papua New Guinea',
#   'elevation': 1807,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 3,
#   'deaths': 13,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': 29.0,
#   'injuries_description': 'Few (~1 to 50 deaths)',
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 13,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': 29.0,
#   'total_injuries_description': 'Few (~1 to 50 deaths)',
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 145.061, 'lat': -4.1},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 2000,
#   'month': '11',
#   'day': '03',
#   'tsu': None,
#   'eq': None,
#   'name': 'Kilauea',
#   'location': 'Hawaiian Is',
#   'country': 'United States',
#   'elevation': 1222,
#   'type': 'Shield volcano',
#   'status': 'Historical',
#   'vei': None,
#   'deaths': 2,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 2,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -155.292, 'lat': 19.425},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 2005,
#   'month': '10',
#   'day': '01',
#   'tsu': None,
#   'eq': None,
#   'name': 'Santa Ana',
#   'location': 'El Salvador',
#   'country': 'El Salvador',
#   'elevation': 2365,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 3,
#   'deaths': 2,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': 'Few (~1 to 50 deaths)',
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 2,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': 'Few (~1 to 50 deaths)',
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -89.63, 'lat': 13.853},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 2006,
#   'month': '05',
#   'day': '20',
#   'tsu': 'Tsunami',
#   'eq': None,
#   'name': 'Soufriere Hills',
#   'location': 'W Indies',
#   'country': 'Montserrat',
#   'elevation': 915,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': 2,
#   'deaths': None,
#   'deaths_description': None,
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': None,
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': -62.18, 'lat': 16.72},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 2015,
#   'month': '04',
#   'day': '22',
#   'tsu': None,
#   'eq': None,
#   'name': 'Calbuco',
#   'location': 'Chile-S',
#   'country': 'Chile',
#   'elevation': 2003,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': None,
#   'deaths': None,
#   'deaths_description': None,
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': 'MODERATE (~$1 to $5 million)',
#   'houses_destroyed': None,
#   'houses_destroyed_description': 'Some (~51 to 100 houses)',
#   'total_deaths': None,
#   'total_deaths_description': None,
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': 'MODERATE (~$1 to $5 million)',
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': 'Some (~51 to 100 houses)',
#   'coordinates': {'lon': -72.614, 'lat': -41.326},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 2017,
#   'month': '09',
#   'day': '12',
#   'tsu': None,
#   'eq': None,
#   'name': 'Campi Flegrei',
#   'location': 'Italy',
#   'country': 'Italy',
#   'elevation': 458,
#   'type': 'Caldera',
#   'status': 'Historical',
#   'vei': None,
#   'deaths': 3,
#   'deaths_description': 'Few (~1 to 50 deaths)',
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': 3,
#   'total_deaths_description': 'Few (~1 to 50 deaths)',
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 14.139, 'lat': 40.827},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 2018,
#   'month': '01',
#   'day': '05',
#   'tsu': None,
#   'eq': None,
#   'name': 'Kadovar',
#   'location': 'New Guinea-NE of',
#   'country': 'Papua New Guinea',
#   'elevation': 365,
#   'type': 'Stratovolcano',
#   'status': 'Holocene',
#   'vei': None,
#   'deaths': None,
#   'deaths_description': None,
#   'missing': None,
#   'missing_description': None,
#   'injuries': None,
#   'injuries_description': None,
#   'damage_millions_dollars': None,
#   'damage_description': 'LIMITED (roughly corresponding to less than $1 million)',
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': None,
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': None,
#   'total_injuries_description': None,
#   'total_damage_millions_dollars': None,
#   'total_damage_description': 'LIMITED (roughly corresponding to less than $1 million)',
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 144.62, 'lat': -3.62},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None},
#  {'year': 2018,
#   'month': '03',
#   'day': '21',
#   'tsu': None,
#   'eq': None,
#   'name': 'Ijen',
#   'location': 'Java',
#   'country': 'Indonesia',
#   'elevation': 2799,
#   'type': 'Stratovolcano',
#   'status': 'Historical',
#   'vei': None,
#   'deaths': None,
#   'deaths_description': None,
#   'missing': None,
#   'missing_description': None,
#   'injuries': 30.0,
#   'injuries_description': 'Few (~1 to 50 deaths)',
#   'damage_millions_dollars': None,
#   'damage_description': None,
#   'houses_destroyed': None,
#   'houses_destroyed_description': None,
#   'total_deaths': None,
#   'total_deaths_description': None,
#   'total_missing': None,
#   'total_missing_description': None,
#   'total_injuries': 30.0,
#   'total_injuries_description': 'Few (~1 to 50 deaths)',
#   'total_damage_millions_dollars': None,
#   'total_damage_description': None,
#   'total_houses_destroyed': None,
#   'total_houses_destroyed_description': None,
#   'coordinates': {'lon': 114.242, 'lat': -8.058},
#   'houses_damaged_description': None,
#   'total_houses_damaged_description': None}]

# %%
content = pd.DataFrame()

# %%
content['year']=list(map(lambda data: data['year'], data))
