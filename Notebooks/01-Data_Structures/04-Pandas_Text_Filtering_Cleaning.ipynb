# %% [markdown]
# # Pandas Text Cleaning and Filtering

# %% [markdown]
# Libraries we need are imported first

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Data used in this exercise is from worldwide airport locations and details

# %%
data_path = '../../DATA/airports.csv'

# %% [markdown]
# The dataframe is created using the .read_csv function

# %%
content = pd.read_csv(data_path)
content
# Out:
#       icao iata                        name        lat         lon    elev  \
# 0     AYGA  GKA                      Goroka  -6.081689  145.391881  1566.0
# 1     AYMD  MAG                      Madang  -5.207083  145.788700     8.0
# 2     AYMH  HGU                 Mount Hagen  -5.826789  144.295861  1636.0
# 3     AYNZ  LAE                      Nadzab  -6.569828  146.726242    65.0
# 4     AYPY  POM  Port Moresby Jacksons Intl  -9.443383  147.220050    50.0
# ...    ...  ...                         ...        ...         ...     ...
# 8887  LFPQ  NaN           Fontenay Tresigny  48.707222    2.904444    98.0
# 8888  KASY  ASY                 ASHLEY MUNI  46.024951  -99.351260   615.0
# 8889  LFDR  NaN            La Reole Floudes  44.568054   -0.056111    20.0
# 8890  SDDR  NaN                     Dracena -21.460511  -51.606898   365.0
# 8891  SLAS  ASC       Ascension De Guarayos -15.719167  -63.091946   217.0
#
#                         tz                        name_ext  \
# ...

# %% [markdown]
# The original CSV file is structured as a dataframe with the corresponding categories

# %%
content= content.dropna()
content
# Out:
#       icao iata             name        lat         lon   elev  \
# 20    CYAM  YAM  Sault Ste Marie  46.485001  -84.509445  180.0
# 23    CYAY  YAY       St Anthony  51.391944  -56.083056   34.0
# 24    CYAZ  YAZ           Tofino  49.082222 -125.772500   40.0
# 25    CYBB  YBB         Kugaaruk  68.534444  -89.808056   10.0
# 26    CYBC  YBC      Baie Comeau  49.132500  -68.204444   13.0
# ...    ...  ...              ...        ...         ...    ...
# 8859  UEMA  MQJ             Moma  66.451035  143.261833  187.0
# 8862  KMRC  MRC         MAURY CO  35.553842  -87.178507  200.0
# 8879  KBBW  BBW  BROKEN BOW MUNI  41.436478  -99.642223  767.0
# 8881  SAZF  OVR        OLAVARRIA -36.888997  -60.220069  163.0
# 8888  KASY  ASY      ASHLEY MUNI  46.024951  -99.351260  615.0
#
#                                   tz                      name_ext  \
# 20                   America/Toronto      Sault Ste. Marie Airport
# 23                  America/St_Johns           St. Anthony Airport
# ...

# %% [markdown]
# Dropping by category

# %%
content = content[content['country'].str.contains('Germany')==True]
content
# Out:
#       icao iata                     name        lat        lon   elev  \
# 286   EDAC  AOC         Altenburg Nobitz  50.981817  12.506361  205.0
# 287   EDBH  BBH                    Barth  54.337540  12.699705    6.0
# 288   EDDC  DRS                  Dresden  51.132767  13.767161  222.0
# 289   EDDE  ERF                   Erfurt  50.979811  10.958106  306.0
# 290   EDDF  FRA           Frankfurt Main  50.026421   8.543125   99.0
# ...    ...  ...                      ...        ...        ...    ...
# 5768  EDQE  URD  Burg Feuerstein Airport  49.794167  11.133611  499.0
# 5772  EDRB  BBJ          Bitburg Airport  49.945278   6.565000  369.0
# 5788  EDWU  VAC      Varrelbusch Airport  52.908333   8.040556   28.0
# 5796  EDXY  OHR    Wyk auf FÃ¶hr Airport  54.684444   8.528333    8.0
# 5999  ETNS  WBG       Schleswig Air Base  54.459301   9.516330   32.0
#
#                  tz                                   name_ext  \
# ...

# %% [markdown]
# To Numeric format

# %% [markdown]
# Display column value

# %%
content["region"].values
# Out:
# array([' Thuringia', ' Mecklenburg-Vorpommern', ' Saxony', ' Thuringia',
#        ' Hessen', ' North Rhine-Westphalia', ' North Rhine-Westphalia',
#        ' North Rhine-Westphalia', ' Bavaria', ' Bavaria', ' Saarland',
#        ' Baden-Württemberg', ' Lower Saxony', ' Bremen',
#        ' Rhineland-Palatinate', ' Baden-Württemberg',
#        ' Schleswig-Holstein', ' Schleswig-Holstein',
#        ' North Rhine-Westphalia', ' North Rhine-Westphalia',
#        ' North Rhine-Westphalia', ' North Rhine-Westphalia', ' Bavaria',
#        ' Bavaria', ' Baden-Württemberg', ' Mecklenburg-Vorpommern',
#        ' Bavaria', ' Bavaria', ' Lower Saxony', ' Hesse', ' Bremen',
#        ' Lower Saxony', ' Lower Saxony', ' Lower Saxony', ' Lower Saxony',
#        ' Schleswig-Holstein', ' Schleswig-Holstein',
#        ' Rhineland-Palatinate', ' Rhineland-Palatinate', ' Bavaria',
#        ' North Rhine-Westphalia', ' Mecklenburg-Vorpommern', ' Bavaria',
# ...

# %% [markdown]
# Sum of column

# %% [markdown]
# Histogram based on pandas

# %%
pd.Series(content["region"]).value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
rankingpost = ranking.sort_values('rank',ascending=False)
rankingpost = rankingpost.reset_index()

# %%
 accukeys.append(vocab_frame.loc[rankingpost['term'][ind].split(' ')].values.tolist()[0][0])

# %%
today = datetime.datetime.now()
content['date'] = pd.to_datetime(content['date'])

# %%
    checkpub = partial['pub'].values[ii] in competitor['pub'].values
    checkslash = '/' in partial['pub'].values[ii]

# %%
partial['reach_acc_off'].replace(np.nan,0, inplace=True)

# %%
partial['reach_acc_dom']=partial['reach'].loc[partial['domain']==1]

# %%
 print(' %s' % vocab_frame.loc[terms[ind].split(' ')].values.tolist()[0][0].encode('utf-8', 'ignore'), end=',')

# %%
content['text'] = list(map(lambda data: data['description'].replace('\n',' '), data))

# %%
content['textarray'] = content['text'].str.lower().str.split()

# %%
content['textlength'] =  content["textarray"].apply(lambda x: len(x))

# %%
content['created'] = pd.to_datetime(content['created'])

# %%
mypanda_per = mypanda_per[mypanda_per.town != '"Rozas De Madrid, Las"']
mypanda_per = mypanda_per[mypanda_per.town != '"Boalo, El"']

mypanda_per_fuen=mypanda_per.loc[mypanda_per['town'] == 'Fuenlabrada']

# %%
a = neu['satellite'].unique()
