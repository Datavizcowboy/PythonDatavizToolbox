# %% [markdown]
# # Regridding NetCDF

# %% [markdown]
# In this example we will put both atmospheric gridded data and SHP data into the same custom grid of our choice.

# %% [markdown]
# We first load useful libraries

# %%
import xarray as xr
import pandas as pd
import numpy as np
from wrf import (getvar, interplevel, to_np, latlon_coords, CoordPair, xy_to_ll, ll_to_xy)
import geopandas as gp
from scipy.interpolate import griddata
import shapely
from shapely.geometry import Polygon
from shapely.geometry import Point
from pyresample.geometry import SwathDefinition
from pyresample.kd_tree import resample_nearest
import rioxarray
import matplotlib.mlab as ml
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.colors as colors
from matplotlib.patches import Circle,RegularPolygon
from mpl_toolkits.axes_grid1 import make_axes_locatable
import cartopy.crs as ccrs
import cartopy
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from cartopy.io import shapereader
import cartopy.io.img_tiles as cimgt
import warnings
warnings.filterwarnings("ignore")
# Out:
# /opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/pyproj/__init__.py:89: UserWarning: pyproj unable to set database path.
#   _pyproj_global_context_initialize()

# %% [markdown]
# We now set the number of columns displayed when inspecting a geopandas

# %%
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## Regridding NetCDF

# %% [markdown]
# Let's start with an .nc file.

# %%
hail_file = '../../DATA/wind.nc'
ds        = xr.open_dataset(hail_file)

# %% [markdown]
# The selected wind speed is the first bucket

# %%
lats=ds.FNOCY.data
lons=ds.FNOCXN79_64.data
var=ds.UWND[0].data

# %% [markdown]
# This is how the wind data looks like:

# %%
Yi = np.linspace(np.min(lats.data),float(np.max(lats.data)),len(lats))
Xi = np.linspace(np.min(lons.data),float(np.max(lons.data)),len(lons))
X, Y = np.meshgrid(Xi,Yi)

# %%
fig,ax = plt.subplots(dpi=144)
# ax.set_ylim(y_min,y_max)
# ax.set_xlim(x_min,x_max)
ax.pcolormesh(lons,lats,var);
ax.plot(X,Y,marker='o', color='k', linestyle='none',ms=.3);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/5k/mjzbrl8j1773drpygwd3n0mm0000gn/T/ipykernel_33786/1598349929.py in <cell line: 4>()
#       2 # ax.set_ylim(y_min,y_max)
#       3 # ax.set_xlim(x_min,x_max)
# ----> 4 ax.pcolormesh(lons,lats,var[0]);
#       5 ax.plot(X,Y,marker='o', color='k', linestyle='none',ms=.3);
#
# /opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1412     def inner(ax, *args, data=None, **kwargs):
#    1413         if data is None:
# -> 1414             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1415
#    1416         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/matplotlib/axes/_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6062         kwargs.setdefault('edgecolors', 'none')
#    6063
# -> 6064         X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
#    6065                                             shading=shading, kwargs=kwargs)
#    6066         coords = np.stack([X, Y], axis=-1)
#
# /opt/anaconda3/envs/geo_env/lib/python3.10/site-packages/matplotlib/axes/_axes.py in _pcolorargs(self, funcname, shading, *args, **kwargs)
#    5547                 if isinstance(Y, np.ma.core.MaskedArray):
#    5548                     Y = Y.data
# -> 5549             nrows, ncols = C.shape
#    5550         else:
#    5551             raise TypeError(f'{funcname}() takes 1 or 3 positional arguments '
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
fig,ax = plt.subplots(dpi=144)
ax.set_ylim(-50,-70)
ax.set_xlim(0,20)
ax.pcolormesh(lons.data,lats.data,var[0].data);
ax.plot(X,Y,marker='o', color='k', linestyle='none',ms=.3);

# %% [markdown]
# We define the new regular mesh grid based on the existing lats and lons and adding a resolution six times (or any other) the existing one.

# %%
Yin = np.linspace(np.min(lats.data),float(np.max(lats.data)),2*len(lats))
Xin = np.linspace(np.min(lons.data),float(np.max(lons.data)),2*len(lons))
Xn, Yn = np.meshgrid(Xin,Yin)

# %% [markdown]
# We can now overlap the new gridpoints onto the previous plot to stop the black new mesh grid.

# %%
fig,ax = plt.subplots(dpi=144)
ax.set_ylim(-50,-70)
ax.set_xlim(0,20)
ax.pcolormesh(lons,lats,var);
ax.plot(lons[:],lats[:],marker='o', color='b', linestyle='none',ms=1);
ax.plot(X[:],Y[:], marker='+', color='black', linestyle='none',ms=1);

# %% [markdown]
# We now regrid the .nc onto the new grid defined by X and Y

# %%
nvals = griddata((lons.values.ravel(),
                                   lats.values.ravel()),
                                   var.values.ravel(),
                                   (X,Y),
                                   method='linear')

# %% [markdown]
# The outcome is the regridded data:

# %%
fig,ax = plt.subplots(dpi=144)
ax.set_ylim(y_min,y_max)
ax.set_xlim(x_min,x_max)
ax.pcolormesh(X,Y,nvals);
ax.plot(X[:],Y[:], marker='+', color='black', linestyle='none',ms=1);

# %% [markdown]
# ## Regridding SHP

# %% [markdown]
# The shapefile describes in this example a river:

# %%
fig,ax = plt.subplots(dpi=144)
ax.set_ylim(y_min,y_max)
ax.set_xlim(x_min,x_max)
df.plot(ax=ax, color='red');

# %% [markdown]
# We now define a shapefile grid with the rectangles containing the original features, on which we will project these features.

# %%
n_cells=100
cell_size = (x_max-x_min)/n_cells
grid_cells = []

for x0 in np.arange(x_min, x_max+cell_size, cell_size ):
    for y0 in np.arange(y_min, y_max+cell_size, cell_size):
        x1 = x0-cell_size
        y1 = y0+cell_size
        grid_cells.append(shapely.geometry.box(x0, y0, x1, y1)  )

# %% [markdown]
# We now convert this shapefile into geopandas and we calculate the position of each centroid of each rectangle of the grid.

# %%
cell = gp.GeoDataFrame(grid_cells, columns=['geometry'])
cell['centroids'] = cell['geometry'].centroid

# %% [markdown]
# The cells look like as follows

# %%
fig,ax = plt.subplots(dpi=144)
ax.set_ylim(y_min,y_max)
ax.set_xlim(x_min,x_max)
cell.plot(ax=ax, facecolor="none", edgecolor='grey');

# %% [markdown]
# The function sjoin allows us to merge the cells and the geopandas.

# %%
merged = gp.sjoin(df, cell)

# %% [markdown]
# We now assign a value to each of the cells based on aggregation

# %%
merged['aggr']=1
dissolve = merged.dissolve(by="index_right", aggfunc="count")
cell.loc[dissolve.index, 'aggr'] = dissolve.aggr.values

# %%
fig,ax2 = plt.subplots(dpi=144)
ax2.set_ylim(y_min,y_max)
ax2.set_xlim(x_min,x_max)
ax2 = cell.plot(column='aggr', figsize=(12, 8), cmap='viridis', vmax=100, edgecolor="grey");

# %% [markdown]
# Finally, we regrid the centroid-based grid into the grid we have defined before.

# %%
x = cell['centroids'].x
y = cell['centroids'].y
z = cell['aggr']

points = (x,y)
values = z

river = griddata(points,
                    values,
                    (X,Y),
                    method='nearest')

# %%
fig,ax = plt.subplots(dpi=144)
ax.set_ylim(y_min,y_max)
ax.set_xlim(x_min,x_max)
ax.pcolormesh(X,Y,nvals)
ax.pcolormesh(X,Y,river,cmap='autumn');
